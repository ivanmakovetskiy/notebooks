# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import os
import re
pd.set_option('display.max_rows', 500)
import scipy
from scipy.stats import skew
from scipy.stats import kurtosis
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../../data/final_data.csv')

# %%
df['salary_from'] = df['salary_from'].fillna(0)
df['salary_to'] = df['salary_to'].fillna(0)
df['salary'] = df.loc[:,'salary_from'] + df.loc[:,'salary_to']
df.loc[(df.salary_from != 0) & (df.salary_to != 0), 'salary'] = df.salary / 2

# %%
df.loc[df.gross == False, 'salary'] = df.salary * 0.87

# %%
df.dropna(axis = 0, subset = ['currency', 'gross'], inplace = True)

# %%
df.drop(['raw', 'schedule', 'employer', 'salary_from', 'salary_to', 'gross'], axis = 1, inplace = True)

# %%
df.drop('employment', axis = 1, inplace = True)

# %%
df.shape
# Out:
# (30639, 11)

# %%
df.isna().sum()
# Out:
# premium                         0
# name                            0
# response_letter_required        0
# city                        10502
# latitude                    10367
# longtitude                  10367
# experience                      0
# skills                       5989
# has_test                        0
# currency                        0
# salary                          0
# dtype: int64

# %%
df = df.loc[~(df.salary == 0)]
df = df.loc[~(df.latitude == 0)]
df = df.loc[~(df.longtitude == 0)]
df.loc[(df.salary < 1000) & (df.currency == 'RUR'), 'salary'] = df.loc[(df.salary < 1000) & (df.currency == 'RUR'), 'salary'] * 1000
df.loc[df.currency == 'USD', 'salary'] = df.salary * 60
df.loc[df.currency == 'EUR', 'salary'] = df.salary * 66
df.loc[df.currency.isin(['EUR', 'USD']), 'currency'] = 'RUR'

# %%
df.dropna(axis = 0, subset = ['latitude', 'longtitude'], inplace = True)

# %%
df.shape
# Out:
# (20144, 11)

# %%
import pickle 
import matplotlib.path as mplPath

# %%
mapper = {
"Алтайский край":"Южно-Сибирский",
"Республика Алтай":"Южно-Сибирский",
"Курская область":"Центрально-Чернозёмный",
"Тульская область":"Центральный",
"Пермский край":"Волго-Камский",
"Тверская область":"Центральный",
"Липецкая область":"Центрально-Чернозёмный",
"Орловская область":"Центральный",
"Самарская область":"Волго-Уральский",
"Кировская область":"Волго-Камский",
"Брянская область":"Центральный",
"Московская область":"Центральный",
"Смоленская область":"Центральный",
"Рязанская область":"Центральный",
"Калужская область":"Центральный",
"Тамбовская область":"Центрально-Чернозёмный",
"Ростовская область":"Южный",
"Республика Марий Эл":"Волго-Камский",
"Курганская область":"Уральско-Сибирский",
"Мурманская область":"Северно-Западный",
"Республика агестан":"Северно-Кавказский",
"Республика Карелия":"Северно-Западный",
"Ивановская область":"Центральный",
"Кемеровская область":"Южно-Сибирский",
"Вологодская область":"Северно-Западный",
"Магаданская область":"Дальневосточный",
"Республика Татарстан":"Волго-Камский",
"Воронежская область":"Центрально-Чернозёмный",
"Белгородская область":"Центрально-Чернозёмный",
"Ярославская область":"Центральный",
"Ульяновская область":"Волго-Уральский",
"Владимирская область":"Центральный",
"Новосибирская область":"Южно-Сибирский",
"Ленинградская область":"Северно-Западный",
"Астраханская область":"Южный",
"Удмуртская Республика":"Волго-Камский",
"Архангельская область":"Северный",
"Чувашская Республика":"Волго-Камский",
"Республика Калмыкия":"Южный",
"Республика Башкортостан":"Волго-Уральский",
"Республика Саха (Якутия)":"Дальневосточный",
"Кабардино-Балкарская Республика":"Северно-Кавказский",
"Республика Северная Осетия-Алания":"Северно-Кавказский",
"Республика Тыва":"Ангаро-Енисейский",
"Карачаево-Черкесская Республика":"Северно-Кавказский",
"Еврейская автономная область":"Дальневосточный",
"Томская область":"Южно-Сибирский",
"Амурская область":"Дальневосточный",
"Пензенская область":"Волго-Уральский",
"Республика Бурятия":"Дальневосточный",
"Республика Хакасия":"Ангаро-Енисейский",
"Республика Мордовия":"Волго-Камский",
"Саратовская область":"Волго-Уральский",
"Костромская область":"Центральный",
"Республика Ингушетия":"Северно-Кавказский",
"Чеченская Республика":"Северно-Кавказский",
"Калининградская область":"Северно-Западный",
"Псковская область":"Северно-Западный",
"Республика Коми":"Северный",
"Оренбургская область":"Волго-Уральский",
"Новгородская область":"Северно-Западный",
"Челябинская область":"Уральско-Сибирский",
"Ставропольский край":"Северно-Кавказский",
"Свердловская область":"Уральско-Сибирский",
"Волгоградская область":"Южный",
"Республика Адыгея":"Южный",
"Ханты-Мансийский автономный округ":"Уральско-Сибирский",
"Тюменская область":"Уральско-Сибирский",
"Омская область":"Южно-Сибирский",
"Приморский край":"Дальневосточный",
"Хабаровский край":"Дальневосточный",
"Сахалинская область":"Дальневосточный",
"Чукотский автономный округ":"Дальневосточный",
"Красноярский край":"Ангаро-Енисейский",
"Иркутская область":"Ангаро-Енисейский",
"Забайкальский край":"Дальневосточный",
"Камчатский край":"Дальневосточный",
"Ненецкий автономный округ":"Северный",
"Ямало-Ненецкий автономный округ":"Уральско-Сибирский",
"Республика Дагестан":"Северно-Кавказский",
"Краснодарский край":"Южный",
"Нижегородская область":"Волго-Камский",
"Неизвестно" : "Неизвестно" }

# %%
def convert_to_region(lat, long):
    coord = np.array([lat, long])
    for reg, area in loaded_dict.items():
        if area.contains_point(coord):
            return reg
    
    return 'Неизвестно'

with open('../../data/saved_dictionary.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)
    
l = []
for v in loaded_dict.values():
    l.append(mplPath.Path(np.array(v['0'])))
    
loaded_dict = dict(zip(list(loaded_dict.keys()), l))
df.loc[:, 'Region'] = df.apply(lambda x: convert_to_region(x.latitude, x.longtitude), axis = 1)

df.loc[:, 'Region'] = df.loc[:, "Region"].map(mapper)

# %%
df.loc[(df["city"].isin(["посёлок Русский","Владивосток","Артёмовский городской округ",
                        "посёлок городского типа Забайкальск","поселок городского типа Забайкальск",
                        "городской округ Владивостокский"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Дальневосточный"
df.loc[(df["city"].isin(["посёлок городского типа Кореиз","село Скворцово","посёлок Розовый",
                        "село Дубки","Керчь","посёлок Волна","Анапа","Евпатория",
                        "Симферополь", "Ялта", "Севастополь", "Таганрог", 
                        "посёлок городского типа Сириус", "Новороссийск","Дербент",
                        "село Яблочное","посёлок городского типа Гвардейское","село Белоглинка",
                        "Избербаш","Махачкала","Республика Крым","посёлок городского типа Красногвардейское",
                        "Сочи","село Фонтаны",])) & (df["Region"] == 'Неизвестно'), "Region"] = "Северно-Кавказский"
df.loc[(df["city"].isin(["Архангельск","Полярный"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Северный"
df.loc[(df["city"].isin(["Санкт-Петербург","Ломоносов","Сосновый Бор"]) & (df["Region"] == 'Неизвестно')) , "Region"] = "Северно-Западный"
df.loc[(df["city"].isin(["посёлок Новый"])) & (df["Region"] == 'Неизвестно'), "Region"] = "Уральский"

df.loc[:, "Region"] = df['Region'].str.replace('^Уральский$','Северный и Уральский')
df.loc[:, "Region"] = df['Region'].str.replace('^Северный$','Северный и Уральский')

# %%
skills = [i.split('_') for i in df.skills.astype(str)]

# %%
skills = pd.Series([item for sublist in skills for item in sublist]).value_counts()

# %%
df.skills = df.skills.astype(str)

# %%
for v in skills[1:54].index: 
    df.loc[:, v] = df.skills.str.contains(re.compile('(^|_)' + re.escape(v) + '(_|$)')).astype(int)

# %%
df.drop(['city', 'skills', 'premium', 'currency'], axis = 1, inplace = True)

# %%
df.Region.value_counts()
# Out:
# Центральный               5918
# Северно-Западный          2897
# Волго-Камский             2263
# Уральско-Сибирский        1820
# Южно-Сибирский            1769
# Волго-Уральский           1416
# Южный                     1346
# Центрально-Чернозёмный     776
# Ангаро-Енисейский          715
# Дальневосточный            699
# Северно-Кавказский         401
# Северный и Уральский        93
# Неизвестно                  31
# Name: Region, dtype: int64

# %%
df.isna().sum()
# Out:
# name                                       0
# response_letter_required                   0
# latitude                                   0
# longtitude                                 0
# experience                                 0
# has_test                                   0
# salary                                     0
# Region                                     0
# Работа в команде                           0
# Пользователь ПК                            0
# Грамотная речь                             0
# Техническое обслуживание                   0
# 1С программирование                        0
# Linux                                      0
# 1С: Предприятие 8                          0
# Работа в условиях многозадачности          0
# SQL                                        0
# Работа с большим объемом информации        0
# Adobe Photoshop                            0
# Настройка ПК                               0
# Грамотность                                0
# Управление проектами                       0
# Git                                        0
# Умение работать в команде                  0
# Настройка сетевых подключений              0
# Организаторские навыки                     0
# Английский язык                            0
# Деловое общение                            0
# Настройка ПО                               0
# Деловая переписка                          0
# Ремонтные работы                           0
# Аналитическое мышление                     0
# JavaScript                                 0
# Ведение переговоров                        0
# Windows 7                                  0
# MS PowerPoint                              0
# Информационные технологии                  0
# Ремонт ПК                                  0
# Техническая поддержка                      0
# HTML                                       0
# Точность и внимательность к деталям        0
# PHP                                        0
# Администрирование сетевого оборудования    0
# MySQL                                      0
# 1С: Документооборот                        0
# Adobe Illustrator                          0
# CorelDRAW                                  0
# Чтение чертежей                            0
# Python                                     0
# Креативность                               0
# Поиск информации в интернет                0
# TCP/IP                                     0
# Монтаж оборудования                        0
# Станки ЧПУ                                 0
# 1С: Управление Торговлей                   0
# 1С: Зарплата и управление персоналом       0
# CSS                                        0
# ООП                                        0
# Деловая коммуникация                       0
# Информационная безопасность                0
# PostgreSQL                                 0
# dtype: int64

# %%
df.to_csv('../../data/final_data_salary.csv', index = False)

# %% [markdown]
# ## Анализ целевой переменной. Поиск выбросов

# %%
df = pd.read_csv('../../data/final_data_salary.csv')

# %%
df.salary.std()
# Out:
# 44979.8379115297

# %%
df.salary.mean()
# Out:
# 68776.57347001591

# %%
df[(df.salary < df.salary.mean() - 3 * df.salary.std()) | (df.salary > df.salary.mean() + 3 * df.salary.std())].head()
# Out:
#                                                   name  \
# 93                       Программист 1C (производство)
# 154  Технический директор в Zapomni (software devel...
# 213                          Blockchain System Analyst
# 217  Руководитель завода электродвигателей, город С...
# 298  Python-разработчик в Цифровые поверхности Салю...
#
#      response_letter_required   latitude  longtitude          experience  \
# 93                      False  55.807800   37.638737  От 1 года до 3 лет
# 154                      True  55.753534   37.611679       От 3 до 6 лет
# 213                     False  23.608705   53.434111  От 1 года до 3 лет
# 217                     False  55.678747   37.511131         Более 6 лет
# 298                     False  55.741338   37.531127       От 3 до 6 лет
#
#      has_test    salary       Region  Работа в команде  Пользователь ПК  ...  \
# 93      False  217500.0  Центральный                 0                0  ...
# 154     False  304500.0  Центральный                 0                0  ...
# 213     False  208800.0   Неизвестно                 0                0  ...
# 217     False  300000.0  Центральный                 0                0  ...
# 298     False  300000.0  Центральный                 0                0  ...
#
#      TCP/IP  Монтаж оборудования  Станки ЧПУ  1С: Управление Торговлей  \
# 93        0                    0           0                         0
# 154       0                    0           0                         0
# 213       0                    0           0                         0
# 217       0                    0           0                         0
# 298       0                    0           0                         0
#
#      1С: Зарплата и управление персоналом  CSS  ООП  Деловая коммуникация  \
# 93                                      0    0    0                     0
# 154                                     0    0    0                     0
# 213                                     0    0    0                     0
# 217                                     0    0    0                     0
# 298                                     0    0    0                     0
#
#      Информационная безопасность  PostgreSQL
# 93                             0           0
# 154                            0           0
# 213                            0           0
# 217                            0           0
# 298                            0           1
#
# [5 rows x 61 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты')

mean = np.mean(df.salary)
std = np.std(df.salary)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

plt.annotate('Потенциальные выбросы', xy=(320000, 0.0000001), xytext=(435000, 0.00001),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('', xy=(520000, 0.0000001), xytext=(430000, 0.00001),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.grid()
plt.show()

# %% [markdown]
# ## Анализ количественных признаков

# %%
df_numeric = df.loc[:, ['latitude', 'longtitude', 'salary']]

# %%
df_numeric.describe()
# Out:
#            latitude    longtitude         salary
# count  20144.000000  20144.000000   20144.000000
# mean      55.031173     50.673507   68776.573470
# std        4.115035     23.116306   44979.837912
# min       23.608705   -117.780920    8700.000000
# 25%       54.197104     37.544997   40000.000000
# 50%       55.749451     39.807944   55000.000000
# 75%       56.837641     57.498475   82500.000000
# max       69.496790    158.679625  522000.000000

# %%
stats = []

for (i, col) in enumerate(df_numeric.columns):
    val = df_numeric[col]
    
    stats.append ([col, val.mean(), val.median(), val.min(), val.max(), val.std(), 
                     scipy.stats.skew(val, axis=0, bias=True), 
                     kurtosis(val, axis=0, bias=True), 
                     val.quantile(0.05), val.quantile(0.95), 
                     val.quantile(0.75) - val.quantile(0.25),
                     0])

# %%
stats = pd.DataFrame(stats, columns=['Переменная', 'Среднее', 'Медиана', 'Минимум', 'Максимум', 
                                     'Ст. Отклонение', 'Асимметрия', 'Эксцесс', 
                                     '5% Проц', '95% Проц', 'Интерквартильный размах', 'Пропущенные наблюдения'])

# %%
stats
# Out:
#    Переменная       Среднее       Медиана      Минимум       Максимум  \
# 0    latitude     55.031173     55.749451    23.608705      69.496790
# 1  longtitude     50.673507     39.807944  -117.780920     158.679625
# 2      salary  68776.573470  55000.000000  8700.000000  522000.000000
#
#    Ст. Отклонение  Асимметрия   Эксцесс       5% Проц       95% Проц  \
# 0        4.115035   -0.999113  2.253621     45.049750      59.971695
# 1       23.116306    1.800073  3.544598     30.307736      92.981642
# 2    44979.837912    2.418418  8.885286  26100.000000  156600.000000
#
#    Интерквартильный размах  Пропущенные наблюдения
# 0                 2.640537                       0
# 1                19.953478                       0
# 2             42500.000000                       0

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.hist(df.latitude, weights = np.ones_like(df.latitude) / len(df.latitude), bins = len(np.histogram_bin_edges(df.latitude, bins='sturges')) - 1) 
plt.ylabel('Относительная частота')
plt.xlabel('Широта')
ax.set_title('Распределение широты. Стерджес')

plt.annotate('Выбросы', xy=(33, 0.01), xytext=(28, 0.085),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('Ассиметрия влево', xy=(52, 0.2), xytext=(48, 0.35),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.xaxis.set_ticks(np.arange(0, 80, 5))
ax.yaxis.set_ticks(np.arange(0, 0.5, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
plt.hist(df.longtitude, weights = np.ones_like(df.longtitude) / len(df.longtitude), 
         bins = len(np.histogram_bin_edges(df.longtitude, bins='sturges')) - 1) 
plt.ylabel('Относительная частота')
plt.xlabel('Долгота')
ax.set_title('Распределение долготы. Стерджес')

plt.annotate('Выбросы', xy=(-110, 0.001), xytext=(-90, 0.08),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('Ассиметрия вправо', xy=(55, 0.20), xytext=(150, 0.32),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')


ax.yaxis.set_ticks(np.arange(0, 0.5, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, weights = np.ones_like(df.salary) / len(df.salary), 
         bins = len(np.histogram_bin_edges(df.salary, bins='sturges')) - 1)

plt.ylabel('Относительная частота')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты. Стерджес')

plt.annotate('Выбросы', xy=(320000, 0.01), xytext=(435000, 0.32),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

plt.annotate('', xy=(520000, 0.01), xytext=(430000, 0.315),
             arrowprops={'arrowstyle':'->'}
             ,horizontalalignment='center')

ax.xaxis.set_ticks(np.arange(0, 550000, 50000))
ax.yaxis.set_ticks(np.arange(0, 0.55, 0.05))

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.salary, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Зарплата')
ax.set_title('Распределение зарплаты')

mean = np.mean(df.salary)
std = np.std(df.salary)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.latitude, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Широта')
ax.set_title('Распределение широты')

mean = np.mean(df.latitude)
std = np.std(df.latitude)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

plt.hist(df.longtitude, density=True, 
         bins = 'sturges')

plt.ylabel('Плотность')
plt.xlabel('Долгота')
ax.set_title('Распределение долготы')

mean = np.mean(df.longtitude)
std = np.std(df.longtitude)
x = np.linspace(mean - 3*std, mean + 3*std, 100)
plt.plot(x, 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2) ), linewidth=2, color='r')

ax.grid()
plt.show()

# %% [markdown]
# ## Анализ качественных признаков

# %% [markdown]
# ## Города

# %% [markdown]
# В большом количестве(10 тысяч) вакансий город не указан. Такие значения мы заполним категорией "Неизвестно". Города, которые попадаются меньше трех раз мы объеденим в одну категорию "Другие", т.к. в таком случае эта категория получается не такой большой по сравнению с другими категориями.

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

le = preprocessing.LabelEncoder()
encoded = pd.Series(le.fit_transform(df.Region))

df1 = encoded.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent', kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Регион', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = le.transform(le.classes_).astype(str)
labels = le.classes_

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['Region'].unique(),
                           pd.value_counts(df['Region'], sort=False),
                           np.around(pd.value_counts(df['Region'], sort=False) / len(df['Region']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['Region'], sort=False) / len(df['Region']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                     Регион  Количество вакансий  Процент  Накопленный процент
# 0            Волго-Камский                 2263     11.2                 11.2
# 1                    Южный                 1346      6.7                 17.9
# 2           Южно-Сибирский                 1769      8.8                 26.7
# 3              Центральный                 5918     29.4                 56.1
# 4          Дальневосточный                  699      3.5                 59.5
# 5        Ангаро-Енисейский                  715      3.5                 63.1
# 6       Уральско-Сибирский                 1820      9.0                 72.1
# 7         Северно-Западный                 2897     14.4                 86.5
# 8          Волго-Уральский                 1416      7.0                 93.5
# 9       Северно-Кавказский                  401      2.0                 95.5
# 10  Центрально-Чернозёмный                  776      3.9                 99.4
# 11    Северный и Уральский                   93      0.5                 99.8
# 12              Неизвестно                   31      0.2                100.0

# %% [markdown]
# ## Сопроводительное письмо

# %% [markdown]
# Данная переменная очень сильно не сбалансирована и вакансии, для которых сопроводительное письмо обязательно для ~1% вакансий.

# %%
df.response_letter_required.value_counts()
# Out:
# False    19914
# True       230
# Name: response_letter_required, dtype: int64

# %%
df.response_letter_required = df.response_letter_required.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.pyplot import figure

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.response_letter_required.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость сопроводительного письма', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()}) 
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['response_letter_required'].unique(),
                           pd.value_counts(df['response_letter_required'], sort=False),
                           np.around(pd.value_counts(df['response_letter_required'], sort=False) / len(df['response_letter_required']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['response_letter_required'], sort=False) / len(df['response_letter_required']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#    Регион  Количество вакансий  Процент  Накопленный процент
# 0       0                19914     98.9                 98.9
# 1       1                  230      1.1                100.0

# %% [markdown]
# ## Тест

# %% [markdown]
# Лишь около 1% вакансий требуют прохождение тестового задания для отклика на вакансию, эта переменная очень не сбалансирована

# %%
df.has_test.value_counts()
# Out:
# False    19983
# True       161
# Name: has_test, dtype: int64

# %%
df.has_test = df.has_test.map({False: 0, True: 1})

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


df1 = df.has_test.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Необходимость прохождения тестового задания', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = ['0', '1']
labels = [ "False", "True"]

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['has_test'].unique(),
                           pd.value_counts(df['has_test'], sort=False),
                           np.around(pd.value_counts(df['has_test'], sort=False) / len(df['has_test']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['has_test'], sort=False) / len(df['has_test']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#    Регион  Количество вакансий  Процент  Накопленный процент
# 0       0                19983     99.2                 99.2
# 1       1                  161      0.8                100.0

# %% [markdown]
# ## Опыт работы

# %% [markdown]
# Требования к опыту работы несбалансированы

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

le = preprocessing.LabelEncoder()
encoded = pd.Series(le.fit_transform(df.experience))
    
df1 = encoded.value_counts(normalize=True)
df1 = df1.rename('percent').reset_index()

g = sns.catplot(x='index', y='percent',kind='bar', data=df1, palette='muted')

g.ax.set_xlabel('Опыт работы', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

for rect in g.ax.patches:
    g.ax.text (rect.get_x() + rect.get_width()  / 2, rect.get_height() + 0.01, round(rect.get_height(), 3), horizontalalignment='center', fontsize = 11)

handltext = le.transform(le.classes_).astype(str)
labels = le.classes_

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()})
g.fig.set_figwidth(10)
g.fig.set_figheight(8)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           df['experience'].unique(),
                           pd.value_counts(df['experience'], sort=False),
                           np.around(pd.value_counts(df['experience'], sort=False) / len(df['experience']) * 100, 1),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(pd.value_counts(df['experience'], sort=False) / len(df['experience']) * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                Регион  Количество вакансий  Процент  Накопленный процент
# 0           Нет опыта                 2803     13.9                 13.9
# 1  От 1 года до 3 лет                11810     58.6                 72.5
# 2       От 3 до 6 лет                 5116     25.4                 97.9
# 3         Более 6 лет                  415      2.1                100.0

# %% [markdown]
# ## Навыки

# %%
one_c = df.loc[:, df.columns.str.contains('1С')].sum(axis=1).apply(lambda x: min([x, 1]))

# %%
df.drop(df.columns[df.columns.str.contains('1С')], axis = 1, inplace = True)
df.loc[:, '1С'] = one_c

# %%
skills_count = df.iloc[:, 8:].sum(axis = 0)

# %%
skills_count = skills_count.sort_values(ascending=False)

skills_per = skills_count / skills_count.values.sum()

# %%
skills_df = pd.DataFrame({'ind': range(skills_per.shape[0]), 'skills': skills_per.index, 'percent': skills_per.values})

# %%
skills_df
# Out:
#     ind                                   skills   percent
# 0     0                         Работа в команде  0.085082
# 1     1                          Пользователь ПК  0.069482
# 2     2                                       1С  0.047679
# 3     3                           Грамотная речь  0.044546
# 4     4                 Техническое обслуживание  0.032642
# 5     5                                    Linux  0.027661
# 6     6        Работа в условиях многозадачности  0.027285
# 7     7                                      SQL  0.024247
# 8     8      Работа с большим объемом информации  0.024090
# 9     9                          Adobe Photoshop  0.023933
# 10   10                             Настройка ПК  0.023557
# 11   11                              Грамотность  0.022461
# 12   12                     Управление проектами  0.022461
# 13   13                                      Git  0.022430
# 14   14                Умение работать в команде  0.021740
# 15   15            Настройка сетевых подключений  0.020487
# 16   16                   Организаторские навыки  0.019986
# 17   17                          Английский язык  0.019516
# 18   18                          Деловое общение  0.019328
# 19   19                             Настройка ПО  0.018702
# 20   20                        Деловая переписка  0.017449
# 21   21                         Ремонтные работы  0.016540
# 22   22                   Аналитическое мышление  0.015632
# 23   23                               JavaScript  0.015601
# 24   24                      Ведение переговоров  0.015569
# 25   25                                Windows 7  0.014817
# 26   26                            MS PowerPoint  0.014755
# 27   27                Информационные технологии  0.014128
# 28   28                                Ремонт ПК  0.014003
# 29   29                    Техническая поддержка  0.013878
# 30   30                                     HTML  0.013846
# 31   31      Точность и внимательность к деталям  0.013470
# 32   32                                      PHP  0.013345
# 33   33  Администрирование сетевого оборудования  0.013314
# 34   34                                    MySQL  0.012812
# 35   35                        Adobe Illustrator  0.012625
# 36   36                                CorelDRAW  0.012625
# 37   37                          Чтение чертежей  0.012374
# 38   38                                   Python  0.012123
# 39   39              Поиск информации в интернет  0.012061
# 40   40                             Креативность  0.012061
# 41   41                                   TCP/IP  0.011904
# 42   42                      Монтаж оборудования  0.011716
# 43   43                               Станки ЧПУ  0.011685
# 44   44                                      CSS  0.011121
# 45   45                                      ООП  0.010996
# 46   46                     Деловая коммуникация  0.010870
# 47   47              Информационная безопасность  0.010745
# 48   48                               PostgreSQL  0.010620

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]

g = sns.catplot(data = skills_df, x = 'ind', y = 'percent', kind='bar', palette='muted')

g.ax.set_xlabel('Навык', fontsize = 15)
g.ax.set_ylabel('Относительная частота', fontsize = 15)

handltext = skills_df.ind.astype(str).values
labels = skills_df.skills.values

t = g.ax.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.ax.patches)]

g.ax.legend(handles, labels, handler_map={tuple : TextHandler()}, loc='upper right')

g.fig.set_figwidth(20)
g.fig.set_figheight(15)

plt.show()

pd.DataFrame(data={key: val for key, val in 
                   zip([
                       "Регион", 
                       "Количество вакансий",
                       "Процент",
                       "Накопленный процент"
                   ], 
                       [
                           skills_count.index.unique(),
                           skills_count.values,
                           (skills_per * 100).round(2),
                           (lambda arr: [np.around(arr[:idx + 1].sum(), 1) for idx in range(len(arr))])(skills_per * 100)
                       ])}
            ).reset_index(drop=True)
# Out:
#                                      Регион  Количество вакансий  Процент  \
# 0                          Работа в команде                 2716     8.51
# 1                           Пользователь ПК                 2218     6.95
# 2                                        1С                 1522     4.77
# 3                            Грамотная речь                 1422     4.45
# 4                  Техническое обслуживание                 1042     3.26
# 5                                     Linux                  883     2.77
# 6         Работа в условиях многозадачности                  871     2.73
# 7                                       SQL                  774     2.42
# 8       Работа с большим объемом информации                  769     2.41
# 9                           Adobe Photoshop                  764     2.39
# 10                             Настройка ПК                  752     2.36
# 11                              Грамотность                  717     2.25
# 12                     Управление проектами                  717     2.25
# 13                                      Git                  716     2.24
# 14                Умение работать в команде                  694     2.17
# 15            Настройка сетевых подключений                  654     2.05
# 16                   Организаторские навыки                  638     2.00
# 17                          Английский язык                  623     1.95
# 18                          Деловое общение                  617     1.93
# 19                             Настройка ПО                  597     1.87
# 20                        Деловая переписка                  557     1.74
# 21                         Ремонтные работы                  528     1.65
# 22                   Аналитическое мышление                  499     1.56
# 23                               JavaScript                  498     1.56
# 24                      Ведение переговоров                  497     1.56
# 25                                Windows 7                  473     1.48
# 26                            MS PowerPoint                  471     1.48
# 27                Информационные технологии                  451     1.41
# 28                                Ремонт ПК                  447     1.40
# 29                    Техническая поддержка                  443     1.39
# 30                                     HTML                  442     1.38
# 31      Точность и внимательность к деталям                  430     1.35
# 32                                      PHP                  426     1.33
# 33  Администрирование сетевого оборудования                  425     1.33
# 34                                    MySQL                  409     1.28
# 35                        Adobe Illustrator                  403     1.26
# 36                                CorelDRAW                  403     1.26
# 37                          Чтение чертежей                  395     1.24
# 38                                   Python                  387     1.21
# 39              Поиск информации в интернет                  385     1.21
# 40                             Креативность                  385     1.21
# 41                                   TCP/IP                  380     1.19
# 42                      Монтаж оборудования                  374     1.17
# 43                               Станки ЧПУ                  373     1.17
# 44                                      CSS                  355     1.11
# 45                                      ООП                  351     1.10
# 46                     Деловая коммуникация                  347     1.09
# 47              Информационная безопасность                  343     1.07
# 48                               PostgreSQL                  339     1.06
#
#     Накопленный процент
# 0                   8.5
# 1                  15.5
# 2                  20.2
# 3                  24.7
# 4                  27.9
# 5                  30.7
# 6                  33.4
# 7                  35.9
# 8                  38.3
# 9                  40.7
# 10                 43.0
# 11                 45.3
# 12                 47.5
# 13                 49.8
# 14                 51.9
# 15                 54.0
# 16                 56.0
# 17                 57.9
# 18                 59.9
# 19                 61.7
# 20                 63.5
# 21                 65.1
# 22                 66.7
# 23                 68.3
# 24                 69.8
# 25                 71.3
# 26                 72.8
# 27                 74.2
# 28                 75.6
# 29                 77.0
# 30                 78.4
# 31                 79.7
# 32                 81.0
# 33                 82.4
# 34                 83.6
# 35                 84.9
# 36                 86.2
# 37                 87.4
# 38                 88.6
# 39                 89.8
# 40                 91.0
# 41                 92.2
# 42                 93.4
# 43                 94.6
# 44                 95.7
# 45                 96.8
# 46                 97.9
# 47                 98.9
# 48                100.0

# %%
df.to_csv('../../data/final_data_models.csv', index = False)

# %% [markdown]
# ## Гипотезы

# %%
df = pd.read_csv('../../data/final_data_models.csv')

# %% [markdown]
# 1-я Гипотеза: Средняя зарплата на вакансиях с требованием знания английского выше, чем без такого требования
# Для проверки этой гипотезы построим диаграмму Бокса-Вискера для категории английский язык

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 15, 10

# %%
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.pyplot import figure

class TextHandler(HandlerBase):
    def create_artists(self, legend, tup ,xdescent, ydescent,
                        width, height, fontsize,trans):
        tx = Text(width/2.,height/2,tup[0], fontsize=fontsize,
                  ha="center", va="center", color=tup[1], fontweight="bold")
        return [tx]


g = sns.boxplot(x='Английский язык', y='salary',data=df, palette='muted')

g.set_xlabel('Требования английского языка', fontsize = 15)
g.set_ylabel('Зарплата', fontsize = 15)

handltext = ['0', '1']
labels = [ "Необязателен", "Обязателен"]

t = g.get_xticklabels()
labeldic = dict(zip(handltext, labels))
labels = [labeldic[h.get_text()]  for h in t]
handles = [(h.get_text(),c.get_fc()) for h,c in zip(t,g.patches)]

g.legend(handles, labels, handler_map={tuple : TextHandler()})
g.set_yticks(np.arange(0, 600000, 50000))

plt.show()

# %% [markdown]
# Мы видим, что и медиана, и 75 квартиль для вакансий с требованием английского языка выше вакансий без такого требования. Проверим равенство медиан с помощью критерия Манна-Уитни.

# %%
_, p = scipy.stats.mannwhitneyu(df[df['Английский язык'] == 1].salary, df[df['Английский язык'] == 0].salary)
print('p-value= ', p)
if p < 0.05: 
    print('Отвергаем гипотезу о равенстве медиан')
else: 
    print('Нет оснований отвергнуть гипотезу о равенстве медиан')
# Out:
# p-value=  1.612993629262742e-57
# Отвергаем гипотезу о равенстве медиан

# %% [markdown]
# 2-я Гипотеза: При росте опыта работы зарплата разработчиков с навыками JavaScript растет быстрее чем для разработчиков с навыками 1С

# %%
one_s = (df[df['1С'] == 1].groupby('experience')['salary'].mean().sort_values().pct_change() * 100)[1:]

# %%
js = (df[df['JavaScript'] == 1].groupby('experience')['salary'].mean().sort_values().pct_change() * 100)[1:]

# %%
df_plot = pd.concat([one_s, js], axis = 0).reset_index()

# %%
df_plot
# Out:
#            experience     salary
# 0  От 1 года до 3 лет  50.510920
# 1       От 3 до 6 лет  40.996543
# 2         Более 6 лет  18.412548
# 3  От 1 года до 3 лет  38.277091
# 4       От 3 до 6 лет  76.609596
# 5         Более 6 лет  44.605466

# %%
df_plot['skill'] = ['1С' for _ in range(3)] + ['Javascript' for _ in range(3)]

# %%
df_plot.salary = df_plot.salary.round(1)

# %%
ax = sns.barplot(data=df_plot, x="experience", y="salary", hue='skill')
for container in ax.containers:
    ax.bar_label(container)

plt.title('Увеличение зарплаты в процентах по сравнению с предыдущей категорией')
plt.xlabel('Опыт работы', fontsize=15)
plt.ylabel('%', fontsize=15)
ax.legend(title='Навыки')
plt.show()

# %% [markdown]
# По графику процентного изменения цены от опыта работы мы видим, что разработчики Javascript работающие от трех лет имеют большую прибавку к зарплате, чем разработчики 1С

# %% [markdown]
# 3-я Гипотеза: 3. При росте опыта работы зарплата операторов станка растет быстрее, чем зарплата фрезеровщиков

# %%
mech = (df[df['name'].str.contains('фрезе', flags=re.IGNORECASE)].groupby('experience')['salary'].mean()\
         .reindex(['Нет опыта', 'От 1 года до 3 лет', 'От 3 до 6 лет', 'Более 6 лет']).pct_change() * 100)[1:]

# %%
oper = (df[df['name'].str.contains('Оператор станка', flags=re.IGNORECASE)].groupby('experience')['salary'].mean()\
         .reindex(['Нет опыта', 'От 1 года до 3 лет', 'От 3 до 6 лет', 'Более 6 лет']).pct_change() * 100)[1:]

# %%
df_plot = pd.concat([mech, oper], axis = 0).reset_index()

# %%
df_plot
# Out:
#            experience     salary
# 0  От 1 года до 3 лет  13.410085
# 1       От 3 до 6 лет  19.158108
# 2         Более 6 лет   6.973756
# 3  От 1 года до 3 лет  19.767129
# 4       От 3 до 6 лет  18.006758
# 5         Более 6 лет  30.621765

# %%
df_plot['skill'] = ['Фрезеровщик' for _ in range(3)] + ['Оператор станка' for _ in range(3)]

# %%
df_plot.salary = df_plot.salary.round(1)

# %%
ax = sns.barplot(data=df_plot, x="experience", y="salary", hue='skill')
for container in ax.containers:
    ax.bar_label(container)

plt.title('Увеличение зарплаты в процентах по сравнению с предыдущей категорией')
plt.xlabel('Опыт работы', fontsize=15)
plt.ylabel('%', fontsize=15)
ax.legend(title='Профессия')
plt.show()

# %% [markdown]
# По графику процентного изменения цены от опыта работы мы видим, что операторы станка имеют большую прибавку к зарплате, чем фрезеровщики

# %% [markdown]
# ## Модель

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels. stats.diagnostic import het_white
from sklearn.metrics import mean_squared_error

# %%
RAND = 42

# %%
df.loc[:, 'Фрезеровщик'] = df['name'].str.contains('фрезе', flags=re.IGNORECASE).astype(int)
df.loc[:, 'Оператор станка'] = df['name'].str.contains('Оператор станка', flags=re.IGNORECASE).astype(int)

# %%
df_encoder = df.copy()
oneh = pd.get_dummies(df_encoder["Region"], prefix = 'Region', drop_first = True)
df_encoder = pd.concat([df_encoder, oneh], axis=1)
df_encoder.drop('Region', axis = 1, inplace = True)

# oneh = pd.get_dummies(df_encoder["experience"], prefix = 'experience', drop_first = True)
# df_encoder = pd.concat([df_encoder, oneh], axis=1)
# df_encoder.drop('experience', axis = 1, inplace = True)
df_encoder['experience'] = df_encoder['experience'].map({'Нет опыта': 0, 'От 1 года до 3 лет': 1, 
                                                        'От 3 до 6 лет': 2, 'Более 6 лет': 3})

df_encoder = df_encoder.set_index('name')

# %%
X = df_encoder.loc[:, df_encoder.columns != 'salary'] 
y = df_encoder.loc[:, 'salary']

# %%
X = sm.add_constant(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RAND)

# %% [markdown]
# Базовая модель

# %%
model_base = sm.OLS(y_train, X_train).fit()

print(model_base.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     149.2
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):               0.00
# Time:                        22:22:14   Log-Likelihood:            -1.9167e+05
# No. Observations:               16115   AIC:                         3.835e+05
# Df Residuals:                   16046   BIC:                         3.840e+05
# Df Model:                          68
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                    2.477e+04   1.11e+04      2.232      0.026    3020.846    4.65e+04
# response_letter_required                  -18.5017   2697.284     -0.007      0.995   -5305.480    5268.477
# latitude                                  342.6885    167.197      2.050      0.040      14.964     670.413
# longtitude                                -77.2653     71.855     -1.075      0.282    -218.109      63.579
# experience                               1.887e+04    433.281     43.558      0.000     1.8e+04    1.97e+04
# has_test                                 1.653e+04   3126.396      5.287      0.000    1.04e+04    2.27e+04
# Работа в команде                        -2516.3894    900.204     -2.795      0.005   -4280.891    -751.888
# Пользователь ПК                         -7534.7672    975.877     -7.721      0.000   -9447.594   -5621.940
# Грамотная речь                          -2103.5204   1265.985     -1.662      0.097   -4584.992     377.951
# Техническое обслуживание                -2136.5789   1482.917     -1.441      0.150   -5043.262     770.104
# Linux                                    2944.8674   1518.076      1.940      0.052     -30.732    5920.467
# Работа в условиях многозадачности       -4498.5776   1388.425     -3.240      0.001   -7220.046   -1777.109
# SQL                                       1.29e+04   1580.045      8.166      0.000    9806.312     1.6e+04
# Работа с большим объемом информации     -9451.5822   1551.396     -6.092      0.000   -1.25e+04   -6410.672
# Adobe Photoshop                         -1.021e+04   2260.307     -4.519      0.000   -1.46e+04   -5783.879
# Настройка ПК                            -5501.3671   2359.795     -2.331      0.020   -1.01e+04    -875.905
# Грамотность                             -5764.9760   1653.504     -3.487      0.000   -9006.029   -2523.923
# Управление проектами                     2.276e+04   1668.921     13.639      0.000    1.95e+04     2.6e+04
# Git                                      2.599e+04   1801.458     14.425      0.000    2.25e+04    2.95e+04
# Умение работать в команде               -5332.8544   1567.489     -3.402      0.001   -8405.308   -2260.400
# Настройка сетевых подключений           -4119.7860   2273.409     -1.812      0.070   -8575.923     336.351
# Организаторские навыки                  -1151.3245   1690.290     -0.681      0.496   -4464.481    2161.832
# Английский язык                          1.462e+04   1629.993      8.968      0.000    1.14e+04    1.78e+04
# Деловое общение                          -178.8873   1834.515     -0.098      0.922   -3774.742    3416.967
# Настройка ПО                             -186.5198   2491.187     -0.075      0.940   -5069.525    4696.485
# Деловая переписка                       -8211.0029   1881.038     -4.365      0.000   -1.19e+04   -4523.958
# Ремонтные работы                        -7430.1834   1984.182     -3.745      0.000   -1.13e+04   -3540.964
# Аналитическое мышление                   -749.2721   1860.065     -0.403      0.687   -4395.207    2896.663
# JavaScript                               1.614e+04   2354.087      6.856      0.000    1.15e+04    2.08e+04
# Ведение переговоров                      1.475e+04   1943.860      7.590      0.000    1.09e+04    1.86e+04
# Windows 7                               -8567.5387   1992.862     -4.299      0.000   -1.25e+04   -4661.306
# MS PowerPoint                            3201.3300   1938.778      1.651      0.099    -598.892    7001.552
# Информационные технологии               -3922.8337   2000.331     -1.961      0.050   -7843.706      -1.961
# Ремонт ПК                                -763.5589   2283.885     -0.334      0.738   -5240.229    3713.112
# Техническая поддержка                   -8362.0394   1985.604     -4.211      0.000   -1.23e+04   -4470.033
# HTML                                    -7391.6284   2629.789     -2.811      0.005   -1.25e+04   -2236.947
# Точность и внимательность к деталям     -8793.7829   1985.738     -4.428      0.000   -1.27e+04   -4901.514
# PHP                                       335.3494   2741.465      0.122      0.903   -5038.229    5708.927
# Администрирование сетевого оборудования -6404.2366   2187.505     -2.928      0.003   -1.07e+04   -2116.482
# MySQL                                   -2985.0110   2697.577     -1.107      0.269   -8272.563    2302.542
# Adobe Illustrator                        1395.6017   2789.968      0.500      0.617   -4073.049    6864.252
# CorelDRAW                               -9880.8050   2501.949     -3.949      0.000   -1.48e+04   -4976.706
# Чтение чертежей                          -497.3768   2115.503     -0.235      0.814   -4643.999    3649.246
# Python                                   1.904e+04   2192.509      8.682      0.000    1.47e+04    2.33e+04
# Креативность                            -4964.3916   2215.764     -2.240      0.025   -9307.538    -621.245
# Поиск информации в интернет             -4034.9773   2125.179     -1.899      0.058   -8200.565     130.610
# TCP/IP                                  -4267.3167   2230.563     -1.913      0.056   -8639.470     104.837
# Монтаж оборудования                     -5091.9107   2174.481     -2.342      0.019   -9354.137    -829.684
# Станки ЧПУ                              -1625.1531   2194.387     -0.741      0.459   -5926.397    2676.090
# CSS                                      1727.8495   3113.973      0.555      0.579   -4375.886    7831.585
# ООП                                      8505.9570   2359.948      3.604      0.000    3880.195    1.31e+04
# Деловая коммуникация                     2332.4377   2293.937      1.017      0.309   -2163.936    6828.812
# Информационная безопасность              4819.7187   2296.624      2.099      0.036     318.078    9321.359
# PostgreSQL                               4.328e+04   2366.082     18.294      0.000    3.86e+04    4.79e+04
# 1С                                       2.525e+04   1077.319     23.437      0.000    2.31e+04    2.74e+04
# Фрезеровщик                             -9813.1624   1547.101     -6.343      0.000   -1.28e+04   -6780.672
# Оператор станка                         -5470.6276   2627.290     -2.082      0.037   -1.06e+04    -320.846
# Region_Волго-Камский                    -5481.5978   3779.902     -1.450      0.147   -1.29e+04    1927.433
# Region_Волго-Уральский                  -8640.6185   3722.072     -2.321      0.020   -1.59e+04   -1344.942
# Region_Дальневосточный                   1.174e+04   3541.252      3.314      0.001    4794.816    1.87e+04
# Region_Неизвестно                        1.377e+05   9271.226     14.852      0.000     1.2e+05    1.56e+05
# Region_Северно-Западный                  6868.4423   5140.536      1.336      0.182   -3207.583    1.69e+04
# Region_Северно-Кавказский               -3505.8919   4951.340     -0.708      0.479   -1.32e+04    6199.288
# Region_Северный и Уральский              -1.22e+04   6128.520     -1.991      0.046   -2.42e+04    -191.563
# Region_Уральско-Сибирский               -4292.9313   3023.087     -1.420      0.156   -1.02e+04    1632.657
# Region_Центрально-Чернозёмный           -4837.9246   4628.922     -1.045      0.296   -1.39e+04    4235.279
# Region_Центральный                       2.257e+04   4493.212      5.024      0.000    1.38e+04    3.14e+04
# Region_Южно-Сибирский                   -2709.5100   2014.845     -1.345      0.179   -6658.832    1239.812
# Region_Южный                            -3573.1845   4528.193     -0.789      0.430   -1.24e+04    5302.580
# ==============================================================================
# Omnibus:                     7406.799   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            66418.483
# Skew:                           1.997   Prob(JB):                         0.00
# Kurtosis:                      12.108   Cond. No.                     4.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print("Значимость переменных")
p_vals = np.around(model_base.pvalues,2)
p_vals
# Out:
# Значимость переменных
# const                                      0.03
# response_letter_required                   0.99
# latitude                                   0.04
# longtitude                                 0.28
# experience                                 0.00
# has_test                                   0.00
# Работа в команде                           0.01
# Пользователь ПК                            0.00
# Грамотная речь                             0.10
# Техническое обслуживание                   0.15
# Linux                                      0.05
# Работа в условиях многозадачности          0.00
# SQL                                        0.00
# Работа с большим объемом информации        0.00
# Adobe Photoshop                            0.00
# Настройка ПК                               0.02
# Грамотность                                0.00
# Управление проектами                       0.00
# Git                                        0.00
# Умение работать в команде                  0.00
# Настройка сетевых подключений              0.07
# Организаторские навыки                     0.50
# Английский язык                            0.00
# Деловое общение                            0.92
# Настройка ПО                               0.94
# Деловая переписка                          0.00
# Ремонтные работы                           0.00
# Аналитическое мышление                     0.69
# JavaScript                                 0.00
# Ведение переговоров                        0.00
# Windows 7                                  0.00
# MS PowerPoint                              0.10
# Информационные технологии                  0.05
# Ремонт ПК                                  0.74
# Техническая поддержка                      0.00
# HTML                                       0.00
# Точность и внимательность к деталям        0.00
# PHP                                        0.90
# Администрирование сетевого оборудования    0.00
# MySQL                                      0.27
# Adobe Illustrator                          0.62
# CorelDRAW                                  0.00
# Чтение чертежей                            0.81
# Python                                     0.00
# Креативность                               0.03
# Поиск информации в интернет                0.06
# TCP/IP                                     0.06
# Монтаж оборудования                        0.02
# Станки ЧПУ                                 0.46
# CSS                                        0.58
# ООП                                        0.00
# Деловая коммуникация                       0.31
# Информационная безопасность                0.04
# PostgreSQL                                 0.00
# 1С                                         0.00
# Фрезеровщик                                0.00
# Оператор станка                            0.04
# Region_Волго-Камский                       0.15
# Region_Волго-Уральский                     0.02
# Region_Дальневосточный                     0.00
# Region_Неизвестно                          0.00
# Region_Северно-Западный                    0.18
# Region_Северно-Кавказский                  0.48
# Region_Северный и Уральский                0.05
# Region_Уральско-Сибирский                  0.16
# Region_Центрально-Чернозёмный              0.30
# Region_Центральный                         0.00
# Region_Южно-Сибирский                      0.18
# Region_Южный                               0.43
# dtype: float64

# %%
print("Коеффициенты при переменных")
print(np.around(model_base.params,2))
# Out:
# Коеффициенты при переменных
# const                                       24772.72
# response_letter_required                      -18.50
# latitude                                      342.69
# longtitude                                    -77.27
# experience                                  18872.68
# has_test                                    16527.90
# Работа в команде                            -2516.39
# Пользователь ПК                             -7534.77
# Грамотная речь                              -2103.52
# Техническое обслуживание                    -2136.58
# Linux                                        2944.87
# Работа в условиях многозадачности           -4498.58
# SQL                                         12903.38
# Работа с большим объемом информации         -9451.58
# Adobe Photoshop                            -10214.33
# Настройка ПК                                -5501.37
# Грамотность                                 -5764.98
# Управление проектами                        22762.62
# Git                                         25985.69
# Умение работать в команде                   -5332.85
# Настройка сетевых подключений               -4119.79
# Организаторские навыки                      -1151.32
# Английский язык                             14617.02
# Деловое общение                              -178.89
# Настройка ПО                                 -186.52
# Деловая переписка                           -8211.00
# Ремонтные работы                            -7430.18
# Аналитическое мышление                       -749.27
# JavaScript                                  16139.48
# Ведение переговоров                         14754.54
# Windows 7                                   -8567.54
# MS PowerPoint                                3201.33
# Информационные технологии                   -3922.83
# Ремонт ПК                                    -763.56
# Техническая поддержка                       -8362.04
# HTML                                        -7391.63
# Точность и внимательность к деталям         -8793.78
# PHP                                           335.35
# Администрирование сетевого оборудования     -6404.24
# MySQL                                       -2985.01
# Adobe Illustrator                            1395.60
# CorelDRAW                                   -9880.80
# Чтение чертежей                              -497.38
# Python                                      19035.33
# Креативность                                -4964.39
# Поиск информации в интернет                 -4034.98
# TCP/IP                                      -4267.32
# Монтаж оборудования                         -5091.91
# Станки ЧПУ                                  -1625.15
# CSS                                          1727.85
# ООП                                          8505.96
# Деловая коммуникация                         2332.44
# Информационная безопасность                  4819.72
# PostgreSQL                                  43284.02
# 1С                                          25249.16
# Фрезеровщик                                 -9813.16
# Оператор станка                             -5470.63
# Region_Волго-Камский                        -5481.60
# Region_Волго-Уральский                      -8640.62
# Region_Дальневосточный                      11736.07
# Region_Неизвестно                          137691.84
# Region_Северно-Западный                      6868.44
# Region_Северно-Кавказский                   -3505.89
# Region_Северный и Уральский                -12204.15
# Region_Уральско-Сибирский                   -4292.93
# Region_Центрально-Чернозёмный               -4837.92
# Region_Центральный                          22574.41
# Region_Южно-Сибирский                       -2709.51
# Region_Южный                                -3573.18
# dtype: float64

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif["features"] = X_train.columns

# %%
vif.sort_values('VIF Factor', ascending = False)
# Out:
#      VIF Factor                                 features
# 0   1574.623564                                    const
# 66    53.595432                       Region_Центральный
# 61    41.610136                  Region_Северно-Западный
# 3     35.208054                               longtitude
# 57    18.047011                     Region_Волго-Камский
# 68    16.266230                             Region_Южный
# 58    11.654059                   Region_Волго-Уральский
# 65    10.087992            Region_Центрально-Чернозёмный
# 64     9.598040                Region_Уральско-Сибирский
# 62     6.100976                Region_Северно-Кавказский
# 2      6.023169                                 latitude
# 59     5.285787                   Region_Дальневосточный
# 67     4.226494                    Region_Южно-Сибирский
# 15     2.597274                             Настройка ПК
# 14     2.401617                          Adobe Photoshop
# 24     2.302429                             Настройка ПО
# 49     2.213314                                      CSS
# 63     2.165593              Region_Северный и Уральский
# 20     2.113440            Настройка сетевых подключений
# 37     2.030383                                      PHP
# 35     1.952251                                     HTML
# 40     1.948962                        Adobe Illustrator
# 39     1.849724                                    MySQL
# 60     1.770358                        Region_Неизвестно
# 28     1.702618                               JavaScript
# 41     1.538713                                CorelDRAW
# 33     1.480358                                Ремонт ПК
# 18     1.442088                                      Git
# 9      1.357942                 Техническое обслуживание
# 8      1.338401                           Грамотная речь
# 38     1.292738  Администрирование сетевого оборудования
# 23     1.248579                          Деловое общение
# 10     1.242724                                    Linux
# 26     1.236295                         Ремонтные работы
# 25     1.212157                        Деловая переписка
# 50     1.211543                                      ООП
# 7      1.207611                          Пользователь ПК
# 30     1.199207                                Windows 7
# 16     1.196811                              Грамотность
# 6      1.191835                         Работа в команде
# 29     1.186557                      Ведение переговоров
# 17     1.186349                     Управление проектами
# 32     1.181006                Информационные технологии
# 53     1.179234                               PostgreSQL
# 43     1.174306                                   Python
# 46     1.173661                                   TCP/IP
# 12     1.171737                                      SQL
# 44     1.161888                             Креативность
# 13     1.150781      Работа с большим объемом информации
# 52     1.139316              Информационная безопасность
# 34     1.109972                    Техническая поддержка
# 42     1.103502                          Чтение чертежей
# 21     1.102546                   Организаторские навыки
# 48     1.095424                               Станки ЧПУ
# 31     1.092387                            MS PowerPoint
# 27     1.086463                   Аналитическое мышление
# 45     1.086064              Поиск информации в интернет
# 4      1.085001                               experience
# 51     1.080158                     Деловая коммуникация
# 55     1.074175                              Фрезеровщик
# 47     1.072025                      Монтаж оборудования
# 19     1.050155                Умение работать в команде
# 56     1.049717                          Оператор станка
# 54     1.049349                                       1С
# 22     1.045042                          Английский язык
# 36     1.029312      Точность и внимательность к деталям
# 11     1.024167        Работа в условиях многозадачности
# 1      1.016165                 response_letter_required
# 5      1.015324                                 has_test

# %%
white_test = het_white(model_base.resid , model_base.model.exog )

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
print(dict(zip(labels, white_test)))
# Out:
# {'Test Statistic': 3828.0050392639732, 'Test Statistic p-value': 2.0687039965425323e-152, 'F-Statistic': 2.518386348544874, 'F-Test p-value': 9.185553930418202e-188}

# %% [markdown]
# Мы принимаем гипотезу о том, что в регрессионной модели присутствует гетероскедастичность.

# %%
p_vals = np.around(model_base.pvalues,2)
p_cols = p_vals[(p_vals > 0.05) & (~p_vals.index.isin(['experience', 'JavaScript', '1С', 
                                                       'Английский язык', 'Фрезеровщик', 'Оператор станка']))]

# %%
p_vals = np.around(model_base.pvalues,2)
p_cols = p_vals[p_vals > 0.05]
X_train_copy = X_train.copy()

while p_cols.any():
    deleted_col = p_cols.index[p_cols.argmax()]
    print('Удаляем колонку ', deleted_col)
    X_train_copy.drop(deleted_col, axis = 1, inplace = True)
    print('Обучаем модель на оставшихся колонках:')
    model = sm.OLS(y_train, X_train_copy).fit()
    print("R-squared:", model.rsquared)
    print("Adj. R-squared:", model.rsquared_adj)
    print("AIC:", model.aic)
    print("Коеффициенты при параметрах")
    print(np.around(model.params, 2))
    
    p_vals = np.around(model.pvalues,2)
    p_cols = p_vals[(p_vals > 0.05) & (~p_vals.index.isin(['experience', 'JavaScript', '1С', 'Английский язык']))]
    
    print('VIF оставшихся колонок:')
    vif = pd.DataFrame()
    vif["VIF Factor"] = [variance_inflation_factor(X_train_copy.values, i) for i in range(X_train_copy.shape[1])]
    vif["features"] = X_train_copy.columns
    print(vif.sort_values('VIF Factor', ascending = False).head(10))
    
    print('Тест Уайта:')
    white_test = het_white(model.resid , model.model.exog )

    #define labels to use for output of White's test
    labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

    #print results of White's test
    print(dict(zip(labels, white_test)))
    print('____________________________________________________________________________________________________________________')
    print('')
# Out:
# Удаляем колонку  response_letter_required
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38743062865253053
# Adj. R-squared: 0.3848730074223766
# AIC: 383483.29763562937
# Коеффициенты при параметрах
# const                                       24771.94
# latitude                                      342.70
# longtitude                                    -77.27
# experience                                  18872.72
# has_test                                    16527.14
# Работа в команде                            -2516.44
# Пользователь ПК                             -7534.86
# Грамотная речь                              -2103.46
# Техническое обслуживание                    -2136.53
# Linux                                        2944.97
# Работа в условиях многозадачности           -4498.53
# SQL                                         12903.45
# Работа с большим объемом информации         -9451.57
# Adobe Photoshop                            -10214.20
# Настройка ПК                                -5501.25
# Грамотность                                 -5765.29
# Управление проектами                        22762.24
# Git                                         25985.22
# Умение работать в команде                   -5332.89
# Настройка сетевых подключений               -4119.82
# Организаторские навыки                      -1151.21
# Английский язык                             14616.59
# Деловое общение                              -178.96
# Настройка ПО                                 -186.56
# Деловая переписка                           -8211.30
# Ремонтные работы                            -7430.17
# Аналитическое мышление                       -749.46
# JavaScript                                  16139.24
# Ведение переговоров                         14754.52
# Windows 7                                   -8567.60
# MS PowerPoint                                3201.24
# Информационные технологии                   -3923.07
# Ремонт ПК                                    -763.48
# Техническая поддержка                       -8362.07
# HTML                                        -7391.55
# Точность и внимательность к деталям         -8793.92
# PHP                                           335.57
# Администрирование сетевого оборудования     -6404.18
# MySQL                                       -2985.30
# Adobe Illustrator                            1395.24
# CorelDRAW                                   -9880.83
# Чтение чертежей                              -497.23
# Python                                      19035.40
# Креативность                                -4964.55
# Поиск информации в интернет                 -4034.96
# TCP/IP                                      -4267.28
# Монтаж оборудования                         -5091.77
# Станки ЧПУ                                  -1625.23
# CSS                                          1727.75
# ООП                                          8505.92
# Деловая коммуникация                         2332.35
# Информационная безопасность                  4819.90
# PostgreSQL                                  43283.89
# 1С                                          25249.15
# Фрезеровщик                                 -9813.13
# Оператор станка                             -5470.55
# Region_Волго-Камский                        -5481.55
# Region_Волго-Уральский                      -8640.61
# Region_Дальневосточный                      11735.94
# Region_Неизвестно                          137690.92
# Region_Северно-Западный                      6868.23
# Region_Северно-Кавказский                   -3505.80
# Region_Северный и Уральский                -12204.17
# Region_Уральско-Сибирский                   -4292.89
# Region_Центрально-Чернозёмный               -4837.87
# Region_Центральный                          22574.31
# Region_Южно-Сибирский                       -2709.48
# Region_Южный                                -3573.27
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1574.457033                          const
# 65    53.594801             Region_Центральный
# 60    41.608656        Region_Северно-Западный
# 2     35.208026                     longtitude
# 56    18.046939           Region_Волго-Камский
# 67    16.266094                   Region_Южный
# 57    11.654057         Region_Волго-Уральский
# 64    10.087961  Region_Центрально-Чернозёмный
# 63     9.598002      Region_Уральско-Сибирский
# 61     6.100932      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3615.9957824201115, 'Test Statistic p-value': 2.7623061515235704e-138, 'F-Statistic': 2.435316727396471, 'F-Test p-value': 2.5934607974281763e-168}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Настройка ПО
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38743041455722727
# Adj. R-squared: 0.3849111228922707
# AIC: 383481.3032678816
# Коеффициенты при параметрах
# const                                       24770.87
# latitude                                      342.65
# longtitude                                    -77.23
# experience                                  18872.82
# has_test                                    16522.36
# Работа в команде                            -2516.98
# Пользователь ПК                             -7532.24
# Грамотная речь                              -2102.55
# Техническое обслуживание                    -2139.63
# Linux                                        2945.38
# Работа в условиях многозадачности           -4498.82
# SQL                                         12902.12
# Работа с большим объемом информации         -9451.50
# Adobe Photoshop                            -10212.28
# Настройка ПК                                -5581.54
# Грамотность                                 -5766.18
# Управление проектами                        22762.36
# Git                                         25985.09
# Умение работать в команде                   -5333.69
# Настройка сетевых подключений               -4167.22
# Организаторские навыки                      -1151.10
# Английский язык                             14618.05
# Деловое общение                              -178.47
# Деловая переписка                           -8211.06
# Ремонтные работы                            -7428.32
# Аналитическое мышление                       -748.16
# JavaScript                                  16139.60
# Ведение переговоров                         14755.69
# Windows 7                                   -8577.97
# MS PowerPoint                                3200.91
# Информационные технологии                   -3923.47
# Ремонт ПК                                    -778.24
# Техническая поддержка                       -8365.92
# HTML                                        -7392.21
# Точность и внимательность к деталям         -8794.27
# PHP                                           335.65
# Администрирование сетевого оборудования     -6407.81
# MySQL                                       -2983.34
# Adobe Illustrator                            1394.39
# CorelDRAW                                   -9881.48
# Чтение чертежей                              -496.94
# Python                                      19036.02
# Креативность                                -4964.53
# Поиск информации в интернет                 -4035.05
# TCP/IP                                      -4259.81
# Монтаж оборудования                         -5090.13
# Станки ЧПУ                                  -1625.59
# CSS                                          1727.48
# ООП                                          8506.44
# Деловая коммуникация                         2332.22
# Информационная безопасность                  4819.75
# PostgreSQL                                  43283.00
# 1С                                          25249.61
# Фрезеровщик                                 -9812.44
# Оператор станка                             -5470.10
# Region_Волго-Камский                        -5480.55
# Region_Волго-Уральский                      -8639.65
# Region_Дальневосточный                      11732.98
# Region_Неизвестно                          137702.02
# Region_Северно-Западный                      6870.02
# Region_Северно-Кавказский                   -3506.40
# Region_Северный и Уральский                -12197.39
# Region_Уральско-Сибирский                   -4292.10
# Region_Центрально-Чернозёмный               -4834.81
# Region_Центральный                          22575.86
# Region_Южно-Сибирский                       -2709.19
# Region_Южный                                -3572.19
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1574.454423                          const
# 64    53.593652             Region_Центральный
# 59    41.607757        Region_Северно-Западный
# 2     35.206429                     longtitude
# 55    18.046715           Region_Волго-Камский
# 66    16.265927                   Region_Южный
# 56    11.653918         Region_Волго-Уральский
# 63    10.087175  Region_Центрально-Чернозёмный
# 62     9.597884      Region_Уральско-Сибирский
# 60     6.100916      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3602.5352733854743, 'Test Statistic p-value': 7.86763059488243e-144, 'F-Statistic': 2.4935434478934124, 'F-Test p-value': 9.654721664865291e-175}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Деловое общение
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38743005324454294
# Adj. R-squared: 0.38494908579865195
# AIC: 383479.3127730094
# Коеффициенты при параметрах
# const                                       24766.00
# latitude                                      342.74
# longtitude                                    -77.29
# experience                                  18874.87
# has_test                                    16522.77
# Работа в команде                            -2524.68
# Пользователь ПК                             -7535.06
# Грамотная речь                              -2118.33
# Техническое обслуживание                    -2138.49
# Linux                                        2944.11
# Работа в условиях многозадачности           -4495.85
# SQL                                         12903.21
# Работа с большим объемом информации         -9455.45
# Adobe Photoshop                            -10211.56
# Настройка ПК                                -5583.53
# Грамотность                                 -5768.99
# Управление проектами                        22762.55
# Git                                         25985.45
# Умение работать в команде                   -5334.89
# Настройка сетевых подключений               -4166.59
# Организаторские навыки                      -1153.84
# Английский язык                             14619.14
# Деловая переписка                           -8262.60
# Ремонтные работы                            -7427.09
# Аналитическое мышление                       -746.90
# JavaScript                                  16140.43
# Ведение переговоров                         14730.01
# Windows 7                                   -8576.34
# MS PowerPoint                                3205.37
# Информационные технологии                   -3922.70
# Ремонт ПК                                    -773.68
# Техническая поддержка                       -8369.56
# HTML                                        -7396.11
# Точность и внимательность к деталям         -8789.97
# PHP                                           335.38
# Администрирование сетевого оборудования     -6407.56
# MySQL                                       -2981.79
# Adobe Illustrator                            1395.92
# CorelDRAW                                   -9884.26
# Чтение чертежей                              -494.32
# Python                                      19036.70
# Креативность                                -4959.57
# Поиск информации в интернет                 -4032.60
# TCP/IP                                      -4257.77
# Монтаж оборудования                         -5088.83
# Станки ЧПУ                                  -1624.35
# CSS                                          1730.07
# ООП                                          8507.36
# Деловая коммуникация                         2318.09
# Информационная безопасность                  4818.96
# PostgreSQL                                  43281.75
# 1С                                          25248.75
# Фрезеровщик                                 -9810.35
# Оператор станка                             -5466.07
# Region_Волго-Камский                        -5481.79
# Region_Волго-Уральский                      -8640.13
# Region_Дальневосточный                      11738.98
# Region_Неизвестно                          137701.53
# Region_Северно-Западный                      6868.92
# Region_Северно-Кавказский                   -3507.61
# Region_Северный и Уральский                -12197.47
# Region_Уральско-Сибирский                   -4292.11
# Region_Центрально-Чернозёмный               -4832.98
# Region_Центральный                          22574.26
# Region_Южно-Сибирский                       -2707.11
# Region_Южный                                -3573.01
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1574.422354                          const
# 63    53.592929             Region_Центральный
# 58    41.607557        Region_Северно-Западный
# 2     35.204189                     longtitude
# 54    18.046510           Region_Волго-Камский
# 65    16.265871                   Region_Южный
# 55    11.653897         Region_Волго-Уральский
# 62    10.087008  Region_Центрально-Чернозёмный
# 61     9.597884      Region_Уральско-Сибирский
# 59     6.100877      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3485.6768781150545, 'Test Statistic p-value': 4.653950343008677e-139, 'F-Statistic': 2.477836088458069, 'F-Test p-value': 9.439893111469802e-168}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  PHP
# Обучаем модель на оставшихся колонках:
# R-squared: 0.387429481818093
# Adj. R-squared: 0.3849868330228505
# AIC: 383477.3278056322
# Коеффициенты при параметрах
# const                                       24779.43
# latitude                                      342.81
# longtitude                                    -77.46
# experience                                  18875.02
# has_test                                    16530.42
# Работа в команде                            -2523.74
# Пользователь ПК                             -7535.41
# Грамотная речь                              -2118.52
# Техническое обслуживание                    -2139.36
# Linux                                        2940.64
# Работа в условиях многозадачности           -4495.96
# SQL                                         12905.64
# Работа с большим объемом информации         -9455.60
# Adobe Photoshop                            -10213.71
# Настройка ПК                                -5584.13
# Грамотность                                 -5771.45
# Управление проектами                        22763.96
# Git                                         26003.63
# Умение работать в команде                   -5335.76
# Настройка сетевых подключений               -4166.61
# Организаторские навыки                      -1155.38
# Английский язык                             14619.26
# Деловая переписка                           -8263.82
# Ремонтные работы                            -7427.46
# Аналитическое мышление                       -747.26
# JavaScript                                  16172.20
# Ведение переговоров                         14729.41
# Windows 7                                   -8573.49
# MS PowerPoint                                3204.93
# Информационные технологии                   -3918.69
# Ремонт ПК                                    -775.27
# Техническая поддержка                       -8369.68
# HTML                                        -7378.83
# Точность и внимательность к деталям         -8790.89
# Администрирование сетевого оборудования     -6407.83
# MySQL                                       -2801.64
# Adobe Illustrator                            1394.34
# CorelDRAW                                   -9882.88
# Чтение чертежей                              -494.98
# Python                                      19026.55
# Креативность                                -4961.30
# Поиск информации в интернет                 -4033.29
# TCP/IP                                      -4262.83
# Монтаж оборудования                         -5089.06
# Станки ЧПУ                                  -1625.29
# CSS                                          1775.78
# ООП                                          8549.46
# Деловая коммуникация                         2317.19
# Информационная безопасность                  4816.08
# PostgreSQL                                  43269.79
# 1С                                          25246.67
# Фрезеровщик                                 -9811.40
# Оператор станка                             -5466.78
# Region_Волго-Камский                        -5489.08
# Region_Волго-Уральский                      -8645.75
# Region_Дальневосточный                      11747.14
# Region_Неизвестно                          137724.09
# Region_Северно-Западный                      6857.64
# Region_Северно-Кавказский                   -3515.86
# Region_Северный и Уральский                -12198.59
# Region_Уральско-Сибирский                   -4297.12
# Region_Центрально-Чернозёмный               -4843.27
# Region_Центральный                          22564.52
# Region_Южно-Сибирский                       -2710.02
# Region_Южный                                -3583.63
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1574.268185                          const
# 62    53.576116             Region_Центральный
# 57    41.594155        Region_Северно-Западный
# 2     35.190250                     longtitude
# 53    18.042022           Region_Волго-Камский
# 64    16.259888                   Region_Южный
# 54    11.652119         Region_Волго-Уральский
# 61    10.083676  Region_Центрально-Чернозёмный
# 60     9.596127      Region_Уральско-Сибирский
# 58     6.099747      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3186.492195362964, 'Test Statistic p-value': 1.9127943389654788e-110, 'F-Statistic': 2.2640362032560466, 'F-Test p-value': 3.2197087538342074e-131}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Чтение чертежей
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38742739129236725
# Adj. R-squared: 0.3850230504819142
# AIC: 383475.38280136505
# Коеффициенты при параметрах
# const                                       24751.64
# latitude                                      343.25
# longtitude                                    -77.46
# experience                                  18872.13
# has_test                                    16537.70
# Работа в команде                            -2536.39
# Пользователь ПК                             -7536.99
# Грамотная речь                              -2109.50
# Техническое обслуживание                    -2133.03
# Linux                                        2943.36
# Работа в условиях многозадачности           -4494.85
# SQL                                         12908.31
# Работа с большим объемом информации         -9455.32
# Adobe Photoshop                            -10213.60
# Настройка ПК                                -5581.64
# Грамотность                                 -5776.90
# Управление проектами                        22767.18
# Git                                         26006.09
# Умение работать в команде                   -5339.48
# Настройка сетевых подключений               -4166.15
# Организаторские навыки                      -1148.66
# Английский язык                             14622.93
# Деловая переписка                           -8260.24
# Ремонтные работы                            -7428.89
# Аналитическое мышление                       -743.62
# JavaScript                                  16175.04
# Ведение переговоров                         14733.05
# Windows 7                                   -8571.95
# MS PowerPoint                                3206.33
# Информационные технологии                   -3917.49
# Ремонт ПК                                    -774.44
# Техническая поддержка                       -8367.41
# HTML                                        -7377.43
# Точность и внимательность к деталям         -8815.41
# Администрирование сетевого оборудования     -6405.14
# MySQL                                       -2800.03
# Adobe Illustrator                            1397.23
# CorelDRAW                                   -9877.51
# Python                                      19028.36
# Креативность                                -4956.22
# Поиск информации в интернет                 -4029.90
# TCP/IP                                      -4261.16
# Монтаж оборудования                         -5090.69
# Станки ЧПУ                                  -1719.89
# CSS                                          1777.04
# ООП                                          8551.21
# Деловая коммуникация                         2321.21
# Информационная безопасность                  4820.13
# PostgreSQL                                  43271.74
# 1С                                          25253.42
# Фрезеровщик                                 -9874.27
# Оператор станка                             -5468.16
# Region_Волго-Камский                        -5492.71
# Region_Волго-Уральский                      -8643.62
# Region_Дальневосточный                      11755.08
# Region_Неизвестно                          137735.85
# Region_Северно-Западный                      6854.77
# Region_Северно-Кавказский                   -3508.11
# Region_Северный и Уральский                -12224.66
# Region_Уральско-Сибирский                   -4302.44
# Region_Центрально-Чернозёмный               -4839.41
# Region_Центральный                          22566.66
# Region_Южно-Сибирский                       -2705.88
# Region_Южный                                -3582.82
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1574.087847                          const
# 61    53.575895             Region_Центральный
# 56    41.593919        Region_Северно-Западный
# 2     35.190250                     longtitude
# 52    18.041718           Region_Волго-Камский
# 63    16.259878                   Region_Южный
# 53    11.652050         Region_Волго-Уральский
# 60    10.083548  Region_Центрально-Чернозёмный
# 59     9.595583      Region_Уральско-Сибирский
# 57     6.099475      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3178.0526401224197, 'Test Statistic p-value': 4.447068442786143e-115, 'F-Statistic': 2.3148332858284797, 'F-Test p-value': 1.5234045185029305e-136}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Ремонт ПК
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38742296671199683
# Adj. R-squared: 0.38505692035865413
# AIC: 383473.49919875886
# Коеффициенты при параметрах
# const                                       24700.97
# latitude                                      343.73
# longtitude                                    -77.28
# experience                                  18875.06
# has_test                                    16531.78
# Работа в команде                            -2541.69
# Пользователь ПК                             -7540.34
# Грамотная речь                              -2108.74
# Техническое обслуживание                    -2235.26
# Linux                                        2941.53
# Работа в условиях многозадачности           -4487.27
# SQL                                         12912.46
# Работа с большим объемом информации         -9459.13
# Adobe Photoshop                            -10215.24
# Настройка ПК                                -5814.37
# Грамотность                                 -5771.59
# Управление проектами                        22766.39
# Git                                         26007.44
# Умение работать в команде                   -5334.58
# Настройка сетевых подключений               -4266.95
# Организаторские навыки                      -1140.71
# Английский язык                             14629.60
# Деловая переписка                           -8265.94
# Ремонтные работы                            -7365.65
# Аналитическое мышление                       -739.95
# JavaScript                                  16175.23
# Ведение переговоров                         14734.77
# Windows 7                                   -8589.38
# MS PowerPoint                                3209.17
# Информационные технологии                   -3887.56
# Техническая поддержка                       -8354.33
# HTML                                        -7376.00
# Точность и внимательность к деталям         -8813.15
# Администрирование сетевого оборудования     -6412.52
# MySQL                                       -2800.59
# Adobe Illustrator                            1399.96
# CorelDRAW                                   -9874.91
# Python                                      19027.48
# Креативность                                -4953.90
# Поиск информации в интернет                 -4030.78
# TCP/IP                                      -4244.80
# Монтаж оборудования                         -5076.90
# Станки ЧПУ                                  -1712.60
# CSS                                          1777.21
# ООП                                          8551.68
# Деловая коммуникация                         2316.82
# Информационная безопасность                  4807.98
# PostgreSQL                                  43273.91
# 1С                                          25255.28
# Фрезеровщик                                 -9871.05
# Оператор станка                             -5465.49
# Region_Волго-Камский                        -5481.33
# Region_Волго-Уральский                      -8638.34
# Region_Дальневосточный                      11749.71
# Region_Неизвестно                          137779.51
# Region_Северно-Западный                      6862.63
# Region_Северно-Кавказский                   -3495.91
# Region_Северный и Уральский                -12232.11
# Region_Уральско-Сибирский                   -4294.87
# Region_Центрально-Чернозёмный               -4829.77
# Region_Центральный                          22577.23
# Region_Южно-Сибирский                       -2701.96
# Region_Южный                                -3564.28
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.804593                          const
# 60    53.573336             Region_Центральный
# 55    41.593081        Region_Северно-Западный
# 2     35.188392                     longtitude
# 51    18.040306           Region_Волго-Камский
# 62    16.257527                   Region_Южный
# 52    11.651847         Region_Волго-Уральский
# 59    10.083170  Region_Центрально-Чернозёмный
# 58     9.595063      Region_Уральско-Сибирский
# 56     6.099155      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3170.4018842987093, 'Test Statistic p-value': 6.460352654777941e-121, 'F-Statistic': 2.3791845198993076, 'F-Test p-value': 2.909669272639239e-143}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Аналитическое мышление
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38741692249145343
# Adj. R-squared: 0.38508916022097306
# AIC: 383471.65820265264
# Коеффициенты при параметрах
# const                                       24708.26
# latitude                                      343.69
# longtitude                                    -77.54
# experience                                  18877.06
# has_test                                    16539.77
# Работа в команде                            -2533.92
# Пользователь ПК                             -7531.02
# Грамотная речь                              -2098.39
# Техническое обслуживание                    -2226.22
# Linux                                        2946.99
# Работа в условиях многозадачности           -4493.35
# SQL                                         12872.05
# Работа с большим объемом информации         -9566.35
# Adobe Photoshop                            -10192.50
# Настройка ПК                                -5798.85
# Грамотность                                 -5768.23
# Управление проектами                        22741.46
# Git                                         26028.93
# Умение работать в команде                   -5321.50
# Настройка сетевых подключений               -4267.12
# Организаторские навыки                      -1134.94
# Английский язык                             14615.13
# Деловая переписка                           -8265.37
# Ремонтные работы                            -7368.97
# JavaScript                                  16174.72
# Ведение переговоров                         14724.96
# Windows 7                                   -8587.30
# MS PowerPoint                                3104.95
# Информационные технологии                   -3903.51
# Техническая поддержка                       -8367.57
# HTML                                        -7371.30
# Точность и внимательность к деталям         -8802.70
# Администрирование сетевого оборудования     -6418.45
# MySQL                                       -2798.20
# Adobe Illustrator                            1395.05
# CorelDRAW                                   -9871.77
# Python                                      19012.55
# Креативность                                -4951.77
# Поиск информации в интернет                 -4027.19
# TCP/IP                                      -4241.58
# Монтаж оборудования                         -5067.52
# Станки ЧПУ                                  -1704.57
# CSS                                          1774.83
# ООП                                          8567.05
# Деловая коммуникация                         2290.32
# Информационная безопасность                  4818.22
# PostgreSQL                                  43285.03
# 1С                                          25249.53
# Фрезеровщик                                 -9859.09
# Оператор станка                             -5456.49
# Region_Волго-Камский                        -5488.02
# Region_Волго-Уральский                      -8642.86
# Region_Дальневосточный                      11754.92
# Region_Неизвестно                          137717.98
# Region_Северно-Западный                      6847.11
# Region_Северно-Кавказский                   -3518.63
# Region_Северный и Уральский                -12231.61
# Region_Уральско-Сибирский                   -4303.91
# Region_Центрально-Чернозёмный               -4839.80
# Region_Центральный                          22563.05
# Region_Южно-Сибирский                       -2702.41
# Region_Южный                                -3580.06
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.800303                          const
# 59    53.569969             Region_Центральный
# 54    41.590686        Region_Северно-Западный
# 2     35.185658                     longtitude
# 50    18.039948           Region_Волго-Камский
# 61    16.256280                   Region_Южный
# 51    11.651739         Region_Волго-Уральский
# 58    10.082871  Region_Центрально-Чернозёмный
# 57     9.594521      Region_Уральско-Сибирский
# 55     6.098343      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3115.343254548759, 'Test Statistic p-value': 8.90404718462432e-123, 'F-Statistic': 2.416259551781411, 'F-Test p-value': 6.713806714051081e-145}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Adobe Illustrator
# Обучаем модель на оставшихся колонках:
# R-squared: 0.387407372972301
# Adj. R-squared: 0.38511787766760053
# AIC: 383469.9094164183
# Коеффициенты при параметрах
# const                                       24791.45
# latitude                                      342.92
# longtitude                                    -77.98
# experience                                  18879.94
# has_test                                    16554.49
# Работа в команде                            -2535.04
# Пользователь ПК                             -7534.01
# Грамотная речь                              -2108.92
# Техническое обслуживание                    -2227.52
# Linux                                        2940.63
# Работа в условиях многозадачности           -4500.71
# SQL                                         12868.00
# Работа с большим объемом информации         -9566.66
# Adobe Photoshop                             -9558.34
# Настройка ПК                                -5803.51
# Грамотность                                 -5789.18
# Управление проектами                        22732.84
# Git                                         26023.64
# Умение работать в команде                   -5325.10
# Настройка сетевых подключений               -4269.20
# Организаторские навыки                      -1151.43
# Английский язык                             14610.50
# Деловая переписка                           -8262.74
# Ремонтные работы                            -7372.70
# JavaScript                                  16160.48
# Ведение переговоров                         14721.31
# Windows 7                                   -8584.73
# MS PowerPoint                                3079.13
# Информационные технологии                   -3906.21
# Техническая поддержка                       -8375.59
# HTML                                        -7392.17
# Точность и внимательность к деталям         -8805.93
# Администрирование сетевого оборудования     -6420.03
# MySQL                                       -2805.95
# CorelDRAW                                   -9717.24
# Python                                      19010.96
# Креативность                                -4938.00
# Поиск информации в интернет                 -4043.43
# TCP/IP                                      -4243.23
# Монтаж оборудования                         -5069.92
# Станки ЧПУ                                  -1713.18
# CSS                                          1773.52
# ООП                                          8562.69
# Деловая коммуникация                         2301.60
# Информационная безопасность                  4815.97
# PostgreSQL                                  43286.94
# 1С                                          25243.72
# Фрезеровщик                                 -9871.02
# Оператор станка                             -5462.47
# Region_Волго-Камский                        -5493.90
# Region_Волго-Уральский                      -8657.56
# Region_Дальневосточный                      11773.46
# Region_Неизвестно                          137679.59
# Region_Северно-Западный                      6827.85
# Region_Северно-Кавказский                   -3559.34
# Region_Северный и Уральский                -12260.49
# Region_Уральско-Сибирский                   -4320.41
# Region_Центрально-Чернозёмный               -4856.53
# Region_Центральный                          22543.60
# Region_Южно-Сибирский                       -2701.53
# Region_Южный                                -3591.55
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.446584                          const
# 58    53.565954             Region_Центральный
# 53    41.588351        Region_Северно-Западный
# 2     35.180231                     longtitude
# 49    18.039774           Region_Волго-Камский
# 60    16.255861                   Region_Южный
# 50    11.651012         Region_Волго-Уральский
# 57    10.082344  Region_Центрально-Чернозёмный
# 56     9.593379      Region_Уральско-Сибирский
# 54     6.096695      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3108.9428643169886, 'Test Statistic p-value': 1.4141441784466686e-127, 'F-Statistic': 2.471630147545091, 'F-Test p-value': 2.1858249964979935e-150}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  CSS
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3873948076717947
# Adj. R-squared: 0.38514356467289323
# AIC: 383468.23995866126
# Коеффициенты при параметрах
# const                                       24841.95
# latitude                                      342.51
# longtitude                                    -78.24
# experience                                  18879.14
# has_test                                    16541.23
# Работа в команде                            -2534.34
# Пользователь ПК                             -7534.86
# Грамотная речь                              -2110.81
# Техническое обслуживание                    -2228.77
# Linux                                        2923.46
# Работа в условиях многозадачности           -4499.76
# SQL                                         12881.29
# Работа с большим объемом информации         -9567.25
# Adobe Photoshop                             -9527.69
# Настройка ПК                                -5806.76
# Грамотность                                 -5784.91
# Управление проектами                        22741.77
# Git                                         26023.54
# Умение работать в команде                   -5325.32
# Настройка сетевых подключений               -4265.70
# Организаторские навыки                      -1167.42
# Английский язык                             14590.54
# Деловая переписка                           -8282.92
# Ремонтные работы                            -7374.04
# JavaScript                                  16592.44
# Ведение переговоров                         14726.25
# Windows 7                                   -8582.69
# MS PowerPoint                                3077.89
# Информационные технологии                   -3917.45
# Техническая поддержка                       -8383.74
# HTML                                        -6533.06
# Точность и внимательность к деталям         -8808.98
# Администрирование сетевого оборудования     -6413.82
# MySQL                                       -2705.68
# CorelDRAW                                   -9738.31
# Python                                      19033.38
# Креативность                                -4953.24
# Поиск информации в интернет                 -4044.55
# TCP/IP                                      -4251.30
# Монтаж оборудования                         -5072.27
# Станки ЧПУ                                  -1713.67
# ООП                                          8547.50
# Деловая коммуникация                         2297.97
# Информационная безопасность                  4811.53
# PostgreSQL                                  43244.36
# 1С                                          25234.21
# Фрезеровщик                                 -9873.95
# Оператор станка                             -5466.18
# Region_Волго-Камский                        -5507.15
# Region_Волго-Уральский                      -8668.60
# Region_Дальневосточный                      11786.51
# Region_Неизвестно                          137542.10
# Region_Северно-Западный                      6810.47
# Region_Северно-Кавказский                   -3576.93
# Region_Северный и Уральский                -12270.64
# Region_Уральско-Сибирский                   -4326.31
# Region_Центрально-Чернозёмный               -4884.33
# Region_Центральный                          22528.67
# Region_Южно-Сибирский                       -2694.96
# Region_Южный                                -3594.39
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1573.347497                          const
# 57    53.564155             Region_Центральный
# 52    41.586906        Region_Северно-Западный
# 2     35.178832                     longtitude
# 48    18.039100           Region_Волго-Камский
# 59    16.255842                   Region_Южный
# 49    11.650700         Region_Волго-Уральский
# 56    10.081238  Region_Центрально-Чернозёмный
# 55     9.593267      Region_Уральско-Сибирский
# 53     6.096461      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3077.666335099658, 'Test Statistic p-value': 3.164756779016812e-130, 'F-Statistic': 2.5124614692051015, 'F-Test p-value': 3.899734311238262e-153}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Организаторские навыки
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38737656733347614
# Adj. R-squared: 0.3851635529404357
# AIC: 383466.7197761354
# Коеффициенты при параметрах
# const                                       24974.42
# latitude                                      340.68
# longtitude                                    -78.57
# experience                                  18857.86
# has_test                                    16511.16
# Работа в команде                            -2593.64
# Пользователь ПК                             -7563.76
# Грамотная речь                              -2131.28
# Техническое обслуживание                    -2239.60
# Linux                                        2934.93
# Работа в условиях многозадачности           -4502.56
# SQL                                         12902.47
# Работа с большим объемом информации         -9553.59
# Adobe Photoshop                             -9535.03
# Настройка ПК                                -5785.39
# Грамотность                                 -5762.55
# Управление проектами                        22558.94
# Git                                         26032.29
# Умение работать в команде                   -5364.72
# Настройка сетевых подключений               -4266.66
# Английский язык                             14602.99
# Деловая переписка                           -8319.36
# Ремонтные работы                            -7379.80
# JavaScript                                  16605.64
# Ведение переговоров                         14635.33
# Windows 7                                   -8574.15
# MS PowerPoint                                3051.99
# Информационные технологии                   -3923.70
# Техническая поддержка                       -8378.89
# HTML                                        -6542.24
# Точность и внимательность к деталям         -8778.55
# Администрирование сетевого оборудования     -6401.46
# MySQL                                       -2695.67
# CorelDRAW                                   -9704.77
# Python                                      19040.90
# Креативность                                -4951.09
# Поиск информации в интернет                 -4015.81
# TCP/IP                                      -4235.79
# Монтаж оборудования                         -5043.06
# Станки ЧПУ                                  -1691.33
# ООП                                          8553.41
# Деловая коммуникация                         2188.92
# Информационная безопасность                  4787.04
# PostgreSQL                                  43247.21
# 1С                                          25257.58
# Фрезеровщик                                 -9845.69
# Оператор станка                             -5426.57
# Region_Волго-Камский                        -5514.14
# Region_Волго-Уральский                      -8679.76
# Region_Дальневосточный                      11786.34
# Region_Неизвестно                          137517.69
# Region_Северно-Западный                      6801.27
# Region_Северно-Кавказский                   -3640.70
# Region_Северный и Уральский                -12290.54
# Region_Уральско-Сибирский                   -4338.99
# Region_Центрально-Чернозёмный               -4917.25
# Region_Центральный                          22520.49
# Region_Южно-Сибирский                       -2685.62
# Region_Южный                                -3626.26
# dtype: float64
# VIF оставшихся колонок:
#      VIF Factor                       features
# 0   1572.877921                          const
# 56    53.563783             Region_Центральный
# 51    41.586627        Region_Северно-Западный
# 2     35.177283                     longtitude
# 47    18.038971           Region_Волго-Камский
# 58    16.254154                   Region_Южный
# 48    11.650481         Region_Волго-Уральский
# 55    10.080171  Region_Центрально-Чернозёмный
# 54     9.592914      Region_Уральско-Сибирский
# 52     6.094343      Region_Северно-Кавказский
# Тест Уайта:
# {'Test Statistic': 3046.416657689238, 'Test Statistic p-value': 1.4422528772283316e-134, 'F-Statistic': 2.5743142373382657, 'F-Test p-value': 8.151868604348928e-158}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Region_Северно-Кавказский
# Обучаем модель на оставшихся колонках:
# R-squared: 0.3873559046700147
# Adj. R-squared: 0.3851811077942715
# AIC: 383465.2632963285
# Коеффициенты при параметрах
# const                                       18754.48
# latitude                                      374.88
# longtitude                                    -37.05
# experience                                  18854.61
# has_test                                    16455.19
# Работа в команде                            -2602.04
# Пользователь ПК                             -7572.65
# Грамотная речь                              -2118.44
# Техническое обслуживание                    -2253.44
# Linux                                        2905.13
# Работа в условиях многозадачности           -4523.58
# SQL                                         12902.32
# Работа с большим объемом информации         -9548.28
# Adobe Photoshop                             -9521.87
# Настройка ПК                                -5804.01
# Грамотность                                 -5792.85
# Управление проектами                        22552.56
# Git                                         26037.30
# Умение работать в команде                   -5379.68
# Настройка сетевых подключений               -4238.98
# Английский язык                             14633.42
# Деловая переписка                           -8340.01
# Ремонтные работы                            -7362.73
# JavaScript                                  16630.24
# Ведение переговоров                         14663.80
# Windows 7                                   -8568.01
# MS PowerPoint                                3052.08
# Информационные технологии                   -3951.40
# Техническая поддержка                       -8342.85
# HTML                                        -6534.51
# Точность и внимательность к деталям         -8765.57
# Администрирование сетевого оборудования     -6401.99
# MySQL                                       -2676.48
# CorelDRAW                                   -9703.39
# Python                                      19061.61
# Креативность                                -4949.44
# Поиск информации в интернет                 -4028.68
# TCP/IP                                      -4250.94
# Монтаж оборудования                         -5045.68
# Станки ЧПУ                                  -1672.67
# ООП                                          8528.71
# Деловая коммуникация                         2188.56
# Информационная безопасность                  4797.11
# PostgreSQL                                  43245.36
# 1С                                          25250.89
# Фрезеровщик                                 -9843.45
# Оператор станка                             -5430.18
# Region_Волго-Камский                        -3292.00
# Region_Волго-Уральский                      -6395.25
# Region_Дальневосточный                      10965.91
# Region_Неизвестно                          141567.22
# Region_Северно-Западный                      9719.77
# Region_Северный и Уральский                -10021.94
# Region_Уральско-Сибирский                   -2646.10
# Region_Центрально-Чернозёмный               -2052.67
# Region_Центральный                          25271.20
# Region_Южно-Сибирский                       -1761.46
# Region_Южный                                 -670.16
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                   features
# 0   658.936151                      const
# 51   16.806512    Region_Северно-Западный
# 55   16.452485         Region_Центральный
# 2    13.458661                 longtitude
# 47    6.515320       Region_Волго-Камский
# 1     5.552929                   latitude
# 49    4.755865     Region_Дальневосточный
# 53    4.032029  Region_Уральско-Сибирский
# 48    3.539117     Region_Волго-Уральский
# 57    3.446259               Region_Южный
# Тест Уайта:
# ...
# Умение работать в команде                   -5376.78
# Настройка сетевых подключений               -4287.74
# Английский язык                             14639.43
# Деловая переписка                           -8268.84
# Ремонтные работы                            -8459.85
# JavaScript                                  16217.54
# Ведение переговоров                         14657.90
# Windows 7                                   -8379.82
# Информационные технологии                   -4039.85
# Техническая поддержка                       -8491.29
# HTML                                        -6860.08
# Точность и внимательность к деталям         -8882.18
# Администрирование сетевого оборудования     -6392.48
# CorelDRAW                                   -9633.65
# Python                                      19160.45
# Креативность                                -4882.27
# Поиск информации в интернет                 -4042.75
# TCP/IP                                      -4262.84
# Монтаж оборудования                         -5538.74
# ООП                                          8173.28
# Информационная безопасность                  5107.17
# PostgreSQL                                  42828.05
# 1С                                          25323.54
# Фрезеровщик                                 -9950.82
# Оператор станка                             -5665.84
# Region_Волго-Уральский                      -4084.15
# Region_Дальневосточный                       9156.95
# Region_Неизвестно                          142066.63
# Region_Северно-Западный                     14133.03
# Region_Центральный                          28563.09
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                       features
# 0   280.203244                          const
# 16    1.910409  Настройка сетевых подключений
# 11    1.805758                   Настройка ПК
# 10    1.633105                Adobe Photoshop
# 1     1.594311                       latitude
# 43    1.557130        Region_Северно-Западный
# 28    1.512118                      CorelDRAW
# 20    1.457596                     JavaScript
# 14    1.394765                            Git
# 25    1.295940                           HTML
# Тест Уайта:
# {'Test Statistic': 2535.785750839, 'Test Statistic p-value': 6.249358882196404e-187, 'F-Statistic': 3.721223725299342, 'F-Test p-value': 7.890358517149139e-211}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  latitude
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38666405560615946
# Adj. R-squared: 0.38502299745116386
# AIC: 383455.45143722196
# Коеффициенты при параметрах
# const                                       34547.82
# experience                                  18917.75
# has_test                                    16368.60
# Работа в команде                            -2760.77
# Пользователь ПК                             -8034.95
# Linux                                        2840.11
# Работа в условиях многозадачности           -4371.70
# SQL                                         12993.57
# Работа с большим объемом информации         -9392.70
# Adobe Photoshop                             -9265.79
# Настройка ПК                                -6184.19
# Грамотность                                 -6627.71
# Управление проектами                        22904.18
# Git                                         25668.05
# Умение работать в команде                   -5352.72
# Настройка сетевых подключений               -4300.23
# Английский язык                             14575.97
# Деловая переписка                           -8211.36
# Ремонтные работы                            -8452.36
# JavaScript                                  16233.87
# Ведение переговоров                         14679.22
# Windows 7                                   -8351.36
# Информационные технологии                   -3999.84
# Техническая поддержка                       -8564.54
# HTML                                        -6896.09
# Точность и внимательность к деталям         -8942.08
# Администрирование сетевого оборудования     -6388.40
# CorelDRAW                                   -9591.86
# Python                                      19083.48
# Креативность                                -4908.02
# Поиск информации в интернет                 -4034.59
# TCP/IP                                      -4279.78
# Монтаж оборудования                         -5562.01
# ООП                                          8137.64
# Информационная безопасность                  5171.32
# PostgreSQL                                  42823.45
# 1С                                          25263.92
# Фрезеровщик                                 -9896.95
# Оператор станка                             -5728.53
# Region_Волго-Уральский                      -4139.52
# Region_Дальневосточный                       8313.88
# Region_Неизвестно                          140022.77
# Region_Северно-Западный                     15013.90
# Region_Центральный                          28837.56
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.099599                                    const
# 15    1.910388            Настройка сетевых подключений
# 10    1.805748                             Настройка ПК
# 9     1.633098                          Adobe Photoshop
# 27    1.511974                                CorelDRAW
# 19    1.457568                               JavaScript
# 13    1.394666                                      Git
# 24    1.295817                                     HTML
# 26    1.289948  Администрирование сетевого оборудования
# 5     1.238120                                    Linux
# Тест Уайта:
# {'Test Statistic': 2500.420517379222, 'Test Statistic p-value': 2.0466505800331867e-193, 'F-Statistic': 3.898353474525205, 'F-Test p-value': 1.647625428660244e-217}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Linux
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38652993829477633
# Adj. R-squared: 0.38492679353422254
# AIC: 383456.97489646624
# Коеффициенты при параметрах
# const                                       34592.02
# experience                                  18936.93
# has_test                                    16351.63
# Работа в команде                            -2781.81
# Пользователь ПК                             -8063.76
# Работа в условиях многозадачности           -4409.27
# SQL                                         13016.18
# Работа с большим объемом информации         -9451.30
# Adobe Photoshop                             -9305.73
# Настройка ПК                                -6261.03
# Грамотность                                 -6647.24
# Управление проектами                        22849.76
# Git                                         26164.24
# Умение работать в команде                   -5357.40
# Настройка сетевых подключений               -4389.37
# Английский язык                             14781.17
# Деловая переписка                           -8136.66
# Ремонтные работы                            -8504.93
# JavaScript                                  16027.77
# Ведение переговоров                         14609.36
# Windows 7                                   -7987.59
# Информационные технологии                   -3899.33
# Техническая поддержка                       -8504.31
# HTML                                        -6773.80
# Точность и внимательность к деталям         -8984.35
# Администрирование сетевого оборудования     -5922.26
# CorelDRAW                                   -9619.62
# Python                                      19887.75
# Креативность                                -4936.86
# Поиск информации в интернет                 -4057.37
# TCP/IP                                      -3594.54
# Монтаж оборудования                         -5607.22
# ООП                                          8320.90
# Информационная безопасность                  5253.74
# PostgreSQL                                  43282.71
# 1С                                          25187.37
# Фрезеровщик                                 -9955.95
# Оператор станка                             -5766.01
# Region_Волго-Уральский                      -4143.53
# Region_Дальневосточный                       8332.88
# Region_Неизвестно                          140239.14
# Region_Северно-Западный                     15043.94
# Region_Центральный                          28838.82
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.092488                                    const
# 14    1.909463            Настройка сетевых подключений
# 9     1.804964                             Настройка ПК
# 8     1.632885                          Adobe Photoshop
# 26    1.511920                                CorelDRAW
# 18    1.453854                               JavaScript
# 12    1.363525                                      Git
# 23    1.294615                                     HTML
# 25    1.273239  Администрирование сетевого оборудования
# 42    1.195506                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2400.9545974556722, 'Test Statistic p-value': 4.942538299880497e-188, 'F-Statistic': 3.9253939916912923, 'F-Test p-value': 2.4607754199348222e-210}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  TCP/IP
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38642764908219673
# Adj. R-squared: 0.3848625108760355
# AIC: 383457.66166694387
# Коеффициенты при параметрах
# const                                       34556.98
# experience                                  18931.57
# has_test                                    16251.88
# Работа в команде                            -2769.75
# Пользователь ПК                             -8055.16
# Работа в условиях многозадачности           -4398.04
# SQL                                         13018.96
# Работа с большим объемом информации         -9455.77
# Adobe Photoshop                             -9264.99
# Настройка ПК                                -5989.37
# Грамотность                                 -6629.23
# Управление проектами                        22870.07
# Git                                         26166.95
# Умение работать в команде                   -5343.15
# Настройка сетевых подключений               -4870.46
# Английский язык                             14766.90
# Деловая переписка                           -8120.89
# Ремонтные работы                            -8478.87
# JavaScript                                  16100.07
# Ведение переговоров                         14641.09
# Windows 7                                   -8297.39
# Информационные технологии                   -3940.64
# Техническая поддержка                       -8717.73
# HTML                                        -6844.44
# Точность и внимательность к деталям         -8954.62
# Администрирование сетевого оборудования     -6624.86
# CorelDRAW                                   -9612.67
# Python                                      19804.93
# Креативность                                -4929.49
# Поиск информации в интернет                 -4043.95
# Монтаж оборудования                         -5525.89
# ООП                                          8357.84
# Информационная безопасность                  5180.04
# PostgreSQL                                  43236.02
# 1С                                          25227.92
# Фрезеровщик                                 -9919.67
# Оператор станка                             -5735.37
# Region_Волго-Уральский                      -4133.83
# Region_Дальневосточный                       8350.16
# Region_Неизвестно                          140084.51
# Region_Северно-Западный                     15048.95
# Region_Центральный                          28819.49
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.086628                                    const
# 14    1.874141            Настройка сетевых подключений
# 9     1.792118                             Настройка ПК
# 8     1.632594                          Adobe Photoshop
# 26    1.511915                                CorelDRAW
# 18    1.453254                               JavaScript
# 12    1.363524                                      Git
# 23    1.294089                                     HTML
# 25    1.223468  Администрирование сетевого оборудования
# 41    1.195136                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2392.16918740419, 'Test Statistic p-value': 3.131688775615115e-195, 'F-Statistic': 4.10117234774124, 'F-Test p-value': 4.329949616877009e-218}
# ____________________________________________________________________________________________________________________
#
# Удаляем колонку  Поиск информации в интернет
# Обучаем модель на оставшихся колонках:
# R-squared: 0.38628867686288204
# Adj. R-squared: 0.3847614619241311
# AIC: 383459.31125077064
# Коеффициенты при параметрах
# const                                       34482.05
# experience                                  18975.12
# has_test                                    16219.88
# Работа в команде                            -2790.38
# Пользователь ПК                             -8344.95
# Работа в условиях многозадачности           -4395.63
# SQL                                         13040.77
# Работа с большим объемом информации         -9627.88
# Adobe Photoshop                             -9291.08
# Настройка ПК                                -5935.17
# Грамотность                                 -7085.97
# Управление проектами                        22916.09
# Git                                         26167.99
# Умение работать в команде                   -5318.54
# Настройка сетевых подключений               -4865.07
# Английский язык                             14790.16
# Деловая переписка                           -8091.79
# Ремонтные работы                            -8398.31
# JavaScript                                  16104.92
# Ведение переговоров                         14619.47
# Windows 7                                   -8362.09
# Информационные технологии                   -3976.28
# Техническая поддержка                       -8802.82
# HTML                                        -6818.16
# Точность и внимательность к деталям         -9050.42
# Администрирование сетевого оборудования     -6646.25
# CorelDRAW                                   -9548.18
# Python                                      19822.78
# Креативность                                -4986.40
# Монтаж оборудования                         -5496.05
# ООП                                          8368.23
# Информационная безопасность                  5198.92
# PostgreSQL                                  43239.29
# 1С                                          25253.18
# Фрезеровщик                                 -9908.80
# Оператор станка                             -5710.63
# Region_Волго-Уральский                      -4140.70
# Region_Дальневосточный                       8331.76
# Region_Неизвестно                          140098.72
# Region_Северно-Западный                     15070.67
# Region_Центральный                          28810.50
# dtype: float64
# VIF оставшихся колонок:
#     VIF Factor                                 features
# 0     6.066908                                    const
# 14    1.874138            Настройка сетевых подключений
# 9     1.791742                             Настройка ПК
# 8     1.632506                          Adobe Photoshop
# 26    1.511634                                CorelDRAW
# 18    1.453252                               JavaScript
# 12    1.363523                                      Git
# 23    1.294036                                     HTML
# 25    1.223434  Администрирование сетевого оборудования
# 40    1.195077                       Region_Центральный
# Тест Уайта:
# {'Test Statistic': 2386.817127093203, 'Test Statistic p-value': 3.990702616684804e-204, 'F-Statistic': 4.323122053891722, 'F-Test p-value': 1.0116193347407742e-227}
# ____________________________________________________________________________________________________________________

# %%
final_columns = X_train_copy.columns
final_columns
# Out:
# Index(['const', 'experience', 'has_test', 'Работа в команде',
#        'Пользователь ПК', 'Работа в условиях многозадачности', 'SQL',
#        'Работа с большим объемом информации', 'Adobe Photoshop',
#        'Настройка ПК', 'Грамотность', 'Управление проектами', 'Git',
#        'Умение работать в команде', 'Настройка сетевых подключений',
#        'Английский язык', 'Деловая переписка', 'Ремонтные работы',
#        'JavaScript', 'Ведение переговоров', 'Windows 7',
#        'Информационные технологии', 'Техническая поддержка', 'HTML',
#        'Точность и внимательность к деталям',
#        'Администрирование сетевого оборудования', 'CorelDRAW', 'Python',
#        'Креативность', 'Монтаж оборудования', 'ООП',
#        'Информационная безопасность', 'PostgreSQL', '1С', 'Фрезеровщик',
#        'Оператор станка', 'Region_Волго-Уральский', 'Region_Дальневосточный',
#        'Region_Неизвестно', 'Region_Северно-Западный', 'Region_Центральный'],
#       dtype='object')

# %% [markdown]
# Проверка гипотез:

# %% [markdown]
# 2-я Гипотеза: При росте опыта работы зарплата разработчиков с навыками JavaScript растет быстрее чем для разработчиков с навыками 1С

# %% [markdown]
# В таком случае коэффициент a("опыт работы") = c1 + b1 * JavaScript + b2 * 1C.
#
# Тогда модель будет иметь следующий вид: ... + c1 * experience + b1 * JavaScript * experience + b2 * experience * 1C ...

# %%
X_hyp2 = X_train_copy.copy()

# %%
X_hyp2
# Out:
#                                                     const  experience  \
# name
# Плазморезчик                                          1.0           2
# Оператор станков с ЧПУ                                1.0           1
# Оператор 1C                                           1.0           1
# Программист 1C                                        1.0           1
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд     1.0           1
# ...                                                   ...         ...
# Инженер-программист АСУ ТП                            1.0           1
# Junior бизнес-аналитик                                1.0           1
# Менеджер по проектам                                  1.0           1
# Менеджер проектов (Project Manager) / Руководит...    1.0           1
# Рабочий по комплексному обслуживанию и ремонту ...    1.0           0
#
#                                                     has_test  \
# name
# Плазморезчик                                               0
# Оператор станков с ЧПУ                                     0
# Оператор 1C                                                0
# Программист 1C                                             0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд          0
# ...                                                      ...
# Инженер-программист АСУ ТП                                 0
# Junior бизнес-аналитик                                     0
# Менеджер по проектам                                       0
# Менеджер проектов (Project Manager) / Руководит...         0
# Рабочий по комплексному обслуживанию и ремонту ...         0
#
#                                                     Работа в команде  \
# name
# Плазморезчик                                                       0
# Оператор станков с ЧПУ                                             0
# Оператор 1C                                                        0
# Программист 1C                                                     0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                  1
# ...                                                              ...
# Инженер-программист АСУ ТП                                         0
# Junior бизнес-аналитик                                             0
# Менеджер по проектам                                               0
# Менеджер проектов (Project Manager) / Руководит...                 0
# Рабочий по комплексному обслуживанию и ремонту ...                 1
#
#                                                     Пользователь ПК  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Работа в условиях многозадачности  \
# name
# Плазморезчик                                                                        0
# Оператор станков с ЧПУ                                                              0
# Оператор 1C                                                                         0
# Программист 1C                                                                      0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                                   0
# ...                                                                               ...
# Инженер-программист АСУ ТП                                                          0
# Junior бизнес-аналитик                                                              0
# Менеджер по проектам                                                                0
# Менеджер проектов (Project Manager) / Руководит...                                  0
# Рабочий по комплексному обслуживанию и ремонту ...                                  1
#
#                                                     SQL  \
# name
# Плазморезчик                                          0
# Оператор станков с ЧПУ                                0
# Оператор 1C                                           0
# Программист 1C                                        0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд     0
# ...                                                 ...
# Инженер-программист АСУ ТП                            0
# Junior бизнес-аналитик                                0
# Менеджер по проектам                                  0
# Менеджер проектов (Project Manager) / Руководит...    0
# Рабочий по комплексному обслуживанию и ремонту ...    0
#
#                                                     Работа с большим объемом информации  \
# name
# Плазморезчик                                                                          0
# Оператор станков с ЧПУ                                                                0
# Оператор 1C                                                                           0
# Программист 1C                                                                        0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                                     0
# ...                                                                                 ...
# Инженер-программист АСУ ТП                                                            0
# Junior бизнес-аналитик                                                                0
# Менеджер по проектам                                                                  0
# Менеджер проектов (Project Manager) / Руководит...                                    0
# Рабочий по комплексному обслуживанию и ремонту ...                                    0
#
#                                                     Adobe Photoshop  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Настройка ПК  ...  \
# name                                                              ...
# Плазморезчик                                                   0  ...
# Оператор станков с ЧПУ                                         0  ...
# Оператор 1C                                                    0  ...
# Программист 1C                                                 0  ...
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд              0  ...
# ...                                                          ...  ...
# Инженер-программист АСУ ТП                                     0  ...
# Junior бизнес-аналитик                                         0  ...
# Менеджер по проектам                                           0  ...
# Менеджер проектов (Project Manager) / Руководит...             0  ...
# Рабочий по комплексному обслуживанию и ремонту ...             0  ...
#
#                                                     Информационная безопасность  \
# name
# Плазморезчик                                                                  0
# Оператор станков с ЧПУ                                                        0
# Оператор 1C                                                                   0
# Программист 1C                                                                0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                             0
# ...                                                                         ...
# Инженер-программист АСУ ТП                                                    0
# Junior бизнес-аналитик                                                        0
# Менеджер по проектам                                                          0
# Менеджер проектов (Project Manager) / Руководит...                            0
# Рабочий по комплексному обслуживанию и ремонту ...                            0
#
#                                                     PostgreSQL  1С  \
# name
# Плазморезчик                                                 0   0
# Оператор станков с ЧПУ                                       0   0
# Оператор 1C                                                  0   1
# Программист 1C                                               0   1
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд            0   0
# ...                                                        ...  ..
# Инженер-программист АСУ ТП                                   0   0
# Junior бизнес-аналитик                                       0   1
# Менеджер по проектам                                         0   0
# Менеджер проектов (Project Manager) / Руководит...           0   0
# Рабочий по комплексному обслуживанию и ремонту ...           0   0
#
#                                                     Фрезеровщик  \
# name
# Плазморезчик                                                  0
# Оператор станков с ЧПУ                                        0
# Оператор 1C                                                   0
# Программист 1C                                                0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд             0
# ...                                                         ...
# Инженер-программист АСУ ТП                                    0
# Junior бизнес-аналитик                                        0
# Менеджер по проектам                                          0
# Менеджер проектов (Project Manager) / Руководит...            0
# Рабочий по комплексному обслуживанию и ремонту ...            0
#
#                                                     Оператор станка  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Region_Волго-Уральский  \
# name
# Плазморезчик                                                             0
# Оператор станков с ЧПУ                                                   1
# Оператор 1C                                                              0
# Программист 1C                                                           0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                        0
# ...                                                                    ...
# Инженер-программист АСУ ТП                                               0
# Junior бизнес-аналитик                                                   0
# Менеджер по проектам                                                     0
# Менеджер проектов (Project Manager) / Руководит...                       0
# Рабочий по комплексному обслуживанию и ремонту ...                       0
#
#                                                     Region_Дальневосточный  \
# name
# Плазморезчик                                                             0
# Оператор станков с ЧПУ                                                   0
# Оператор 1C                                                              0
# Программист 1C                                                           0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                        0
# ...                                                                    ...
# Инженер-программист АСУ ТП                                               0
# Junior бизнес-аналитик                                                   1
# Менеджер по проектам                                                     0
# Менеджер проектов (Project Manager) / Руководит...                       0
# Рабочий по комплексному обслуживанию и ремонту ...                       0
#
#                                                     Region_Неизвестно  \
# name
# Плазморезчик                                                        0
# Оператор станков с ЧПУ                                              0
# Оператор 1C                                                         0
# Программист 1C                                                      0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                   0
# ...                                                               ...
# Инженер-программист АСУ ТП                                          0
# Junior бизнес-аналитик                                              0
# Менеджер по проектам                                                0
# Менеджер проектов (Project Manager) / Руководит...                  0
# Рабочий по комплексному обслуживанию и ремонту ...                  0
#
#                                                     Region_Северно-Западный  \
# name
# Плазморезчик                                                              0
# Оператор станков с ЧПУ                                                    0
# Оператор 1C                                                               0
# Программист 1C                                                            0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                         0
# ...                                                                     ...
# Инженер-программист АСУ ТП                                                0
# Junior бизнес-аналитик                                                    0
# Менеджер по проектам                                                      0
# Менеджер проектов (Project Manager) / Руководит...                        0
# Рабочий по комплексному обслуживанию и ремонту ...                        1
#
#                                                     Region_Центральный
# name
# Плазморезчик                                                         0
# Оператор станков с ЧПУ                                               0
# Оператор 1C                                                          0
# Программист 1C                                                       0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                    1
# ...                                                                ...
# Инженер-программист АСУ ТП                                           0
# Junior бизнес-аналитик                                               0
# Менеджер по проектам                                                 1
# Менеджер проектов (Project Manager) / Руководит...                   0
# Рабочий по комплексному обслуживанию и ремонту ...                   0
#
# [16115 rows x 41 columns]

# %%
X_hyp2.loc[:, 'JS_exp'] = X_hyp2.loc[:, 'JavaScript'] * X_hyp2.loc[:, 'experience']
X_hyp2.loc[:, '1C_exp'] = X_hyp2.loc[:, '1С'] * X_hyp2.loc[:, 'experience']

# %%
model_hyp = sm.OLS(y_train, X_hyp2).fit()

# %%
print("R-squared:", model_hyp.rsquared)
print("Adj. R-squared:", model_hyp.rsquared_adj)
print("AIC:", model_hyp.aic)
print("Коеффициенты при параметрах")
print(np.around(model_hyp.params, 2))
# Out:
# R-squared: 0.3899512123947009
# Adj. R-squared: 0.38835700824590647
# AIC: 383366.85127336025
# Коеффициенты при параметрах
# const                                       35818.69
# experience                                  17820.34
# has_test                                    16674.73
# Работа в команде                            -2915.59
# Пользователь ПК                             -8447.78
# Работа в условиях многозадачности           -4254.19
# SQL                                         13141.83
# Работа с большим объемом информации         -9539.97
# Adobe Photoshop                             -9160.59
# Настройка ПК                                -5998.93
# Грамотность                                 -7111.80
# Управление проектами                        22990.02
# Git                                         25459.55
# Умение работать в команде                   -5396.75
# Настройка сетевых подключений               -4869.32
# Английский язык                             14872.77
# Деловая переписка                           -7943.18
# Ремонтные работы                            -8173.71
# JavaScript                                 -12804.27
# Ведение переговоров                         14719.98
# Windows 7                                   -8364.19
# Информационные технологии                   -3788.01
# Техническая поддержка                       -8814.72
# HTML                                        -6309.68
# Точность и внимательность к деталям         -8926.02
# Администрирование сетевого оборудования     -6474.99
# CorelDRAW                                   -9673.34
# Python                                      20046.45
# Креативность                                -4978.21
# Монтаж оборудования                         -5579.23
# ООП                                          9049.88
# Информационная безопасность                  5146.20
# PostgreSQL                                  43056.22
# 1С                                          11955.33
# Фрезеровщик                                 -9787.17
# Оператор станка                             -5893.01
# Region_Волго-Уральский                      -4073.45
# Region_Дальневосточный                       8451.43
# Region_Неизвестно                          136663.22
# Region_Северно-Западный                     15127.79
# Region_Центральный                          28664.15
# JS_exp                                      22934.88
# 1C_exp                                      10276.05
# dtype: float64

# %%
p_vals = np.around(model_hyp.pvalues,2)
p_vals
# Out:
# const                                      0.00
# experience                                 0.00
# has_test                                   0.00
# Работа в команде                           0.00
# Пользователь ПК                            0.00
# Работа в условиях многозадачности          0.00
# SQL                                        0.00
# Работа с большим объемом информации        0.00
# Adobe Photoshop                            0.00
# Настройка ПК                               0.00
# Грамотность                                0.00
# Управление проектами                       0.00
# Git                                        0.00
# Умение работать в команде                  0.00
# Настройка сетевых подключений              0.02
# Английский язык                            0.00
# Деловая переписка                          0.00
# Ремонтные работы                           0.00
# JavaScript                                 0.00
# Ведение переговоров                        0.00
# Windows 7                                  0.00
# Информационные технологии                  0.06
# Техническая поддержка                      0.00
# HTML                                       0.00
# Точность и внимательность к деталям        0.00
# Администрирование сетевого оборудования    0.00
# CorelDRAW                                  0.00
# Python                                     0.00
# Креативность                               0.02
# Монтаж оборудования                        0.01
# ООП                                        0.00
# Информационная безопасность                0.02
# PostgreSQL                                 0.00
# 1С                                         0.00
# Фрезеровщик                                0.00
# Оператор станка                            0.02
# Region_Волго-Уральский                     0.00
# Region_Дальневосточный                     0.00
# Region_Неизвестно                          0.00
# Region_Северно-Западный                    0.00
# Region_Центральный                         0.00
# JS_exp                                     0.00
# 1C_exp                                     0.00
# dtype: float64

# %% [markdown]
# В таком случае коэффициент a("опыт работы") = c1 + b1 * Фрезеровщик + b2 * Оператор станка.
#
# Тогда модель будет иметь следующий вид: ... + c1 * experience + b1 * Фрезеровщик * experience + b2 * experience * Оператор станка ...

# %%
X_hyp3 = X_train_copy.copy()

# %%
X_hyp3.loc[:, 'Фрезеровщик_exp'] = X_hyp3.loc[:, 'Фрезеровщик'] * X_hyp3.loc[:, 'experience']
X_hyp3.loc[:, 'Оператор_exp'] = X_hyp3.loc[:, 'Оператор станка'] * X_hyp3.loc[:, 'experience']
# X_hyp3.drop(['Фрезеровщик', ])

# %%
model_hyp = sm.OLS(y_train, X_hyp3).fit()

# %%
print("R-squared:", model_hyp.rsquared)
print("Adj. R-squared:", model_hyp.rsquared_adj)
print("AIC:", model_hyp.aic)
print("Коеффициенты при параметрах")
print(np.around(model_hyp.params, 2))
# Out:
# R-squared: 0.38781091017370684
# Adj. R-squared: 0.3862111129006416
# AIC: 383423.2903777006
# Коеффициенты при параметрах
# const                                       33819.19
# experience                                  19516.87
# has_test                                    16312.18
# Работа в команде                            -2855.63
# Пользователь ПК                             -8187.89
# Работа в условиях многозадачности           -4378.30
# SQL                                         13027.49
# Работа с большим объемом информации         -9546.24
# Adobe Photoshop                             -9308.43
# Настройка ПК                                -5919.15
# Грамотность                                 -6975.36
# Управление проектами                        22767.93
# Git                                         26091.64
# Умение работать в команде                   -5338.52
# Настройка сетевых подключений               -4804.96
# Английский язык                             14719.44
# Деловая переписка                           -8064.99
# Ремонтные работы                            -8523.89
# JavaScript                                  16073.00
# Ведение переговоров                         14663.61
# Windows 7                                   -8327.77
# Информационные технологии                   -3964.15
# Техническая поддержка                       -8754.01
# HTML                                        -6771.45
# Точность и внимательность к деталям         -8673.28
# Администрирование сетевого оборудования     -6750.73
# CorelDRAW                                   -9516.92
# Python                                      19799.93
# Креативность                                -4961.67
# Монтаж оборудования                         -5488.12
# ООП                                          8465.58
# Информационная безопасность                  5139.97
# PostgreSQL                                  43137.26
# 1С                                          25170.17
# Фрезеровщик                                  7461.90
# Оператор станка                              3676.14
# Region_Волго-Уральский                      -4096.74
# Region_Дальневосточный                       8400.92
# Region_Неизвестно                          139712.52
# Region_Северно-Западный                     15266.27
# Region_Центральный                          28792.18
# Фрезеровщик_exp                            -14122.92
# Оператор_exp                               -10018.38
# dtype: float64

# %%
p_vals = np.around(model_hyp.pvalues,2)
p_vals
# Out:
# const                                      0.00
# experience                                 0.00
# has_test                                   0.00
# Работа в команде                           0.00
# Пользователь ПК                            0.00
# Работа в условиях многозадачности          0.00
# SQL                                        0.00
# Работа с большим объемом информации        0.00
# Adobe Photoshop                            0.00
# Настройка ПК                               0.00
# Грамотность                                0.00
# Управление проектами                       0.00
# Git                                        0.00
# Умение работать в команде                  0.00
# Настройка сетевых подключений              0.02
# Английский язык                            0.00
# Деловая переписка                          0.00
# Ремонтные работы                           0.00
# JavaScript                                 0.00
# Ведение переговоров                        0.00
# Windows 7                                  0.00
# Информационные технологии                  0.05
# Техническая поддержка                      0.00
# HTML                                       0.00
# Точность и внимательность к деталям        0.00
# Администрирование сетевого оборудования    0.00
# CorelDRAW                                  0.00
# Python                                     0.00
# Креативность                               0.02
# Монтаж оборудования                        0.01
# ООП                                        0.00
# Информационная безопасность                0.02
# PostgreSQL                                 0.00
# 1С                                         0.00
# Фрезеровщик                                0.02
# Оператор станка                            0.46
# Region_Волго-Уральский                     0.00
# Region_Дальневосточный                     0.00
# Region_Неизвестно                          0.00
# Region_Северно-Западный                    0.00
# Region_Центральный                         0.00
# Фрезеровщик_exp                            0.00
# Оператор_exp                               0.03
# dtype: float64

# %% [markdown]
# 2

# %%
preds_base = model_base.predict(X_test)
preds_final = model.predict(X_test.loc[:, final_columns])

# %%
forecast_errors = np.array([actual - forecast for actual, forecast in zip(y_test, preds_base)])

# %%
forecast_errors = np.array([actual - forecast for actual, forecast in zip(y_test, preds_base)])

# Calculate the mean and standard deviation of the forecast errors
mean_sq_error = mean_squared_error(y_test, preds_base)
print('Среднеквадратическая погрешность ', mean_sq_error)
std_forecast_error = np.std(forecast_errors)

# Calculate the standard error of the forecast
sample_size = len(forecast_errors)
se = std_forecast_error / np.sqrt(sample_size)

# Calculate the maximum absolute error of forecasting
mae = np.max(np.abs(forecast_errors))
print('Абсолютная погрешность ', mae)

scipy.stats.t.interval(alpha=0.95, df=len(forecast_errors)-1,
              loc=np.mean(forecast_errors),
              scale=scipy.stats.sem(forecast_errors))
# Out:
# Среднеквадратическая погрешность  1211233027.4206047
# Абсолютная погрешность  288546.92378381506
# (-1532.2584503520484, 617.7503632278244)

# %%
forecast_errors = np.array([actual - forecast for actual, forecast in zip(y_test, preds_final)])

# Calculate the mean and standard deviation of the forecast errors
mean_sq_error = mean_squared_error(y_test, preds_base)
print('Среднеквадратическая погрешность ', mean_sq_error)
std_forecast_error = np.std(forecast_errors)

# Calculate the standard error of the forecast
sample_size = len(forecast_errors)
se = std_forecast_error / np.sqrt(sample_size)

# Calculate the maximum absolute error of forecasting
mae = np.max(np.abs(forecast_errors))
print('Абсолютная погрешность ', mae)
# Out:
# Среднеквадратическая погрешность  1211233027.4206047
# Абсолютная погрешность  283979.22008556523

# %%
X_train_copy
# Out:
#                                                     const  experience  \
# name
# Плазморезчик                                          1.0           2
# Оператор станков с ЧПУ                                1.0           1
# Оператор 1C                                           1.0           1
# Программист 1C                                        1.0           1
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд     1.0           1
# ...                                                   ...         ...
# Инженер-программист АСУ ТП                            1.0           1
# Junior бизнес-аналитик                                1.0           1
# Менеджер по проектам                                  1.0           1
# Менеджер проектов (Project Manager) / Руководит...    1.0           1
# Рабочий по комплексному обслуживанию и ремонту ...    1.0           0
#
#                                                     has_test  \
# name
# Плазморезчик                                               0
# Оператор станков с ЧПУ                                     0
# Оператор 1C                                                0
# Программист 1C                                             0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд          0
# ...                                                      ...
# Инженер-программист АСУ ТП                                 0
# Junior бизнес-аналитик                                     0
# Менеджер по проектам                                       0
# Менеджер проектов (Project Manager) / Руководит...         0
# Рабочий по комплексному обслуживанию и ремонту ...         0
#
#                                                     Работа в команде  \
# name
# Плазморезчик                                                       0
# Оператор станков с ЧПУ                                             0
# Оператор 1C                                                        0
# Программист 1C                                                     0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                  1
# ...                                                              ...
# Инженер-программист АСУ ТП                                         0
# Junior бизнес-аналитик                                             0
# Менеджер по проектам                                               0
# Менеджер проектов (Project Manager) / Руководит...                 0
# Рабочий по комплексному обслуживанию и ремонту ...                 1
#
#                                                     Пользователь ПК  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Работа в условиях многозадачности  \
# name
# Плазморезчик                                                                        0
# Оператор станков с ЧПУ                                                              0
# Оператор 1C                                                                         0
# Программист 1C                                                                      0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                                   0
# ...                                                                               ...
# Инженер-программист АСУ ТП                                                          0
# Junior бизнес-аналитик                                                              0
# Менеджер по проектам                                                                0
# Менеджер проектов (Project Manager) / Руководит...                                  0
# Рабочий по комплексному обслуживанию и ремонту ...                                  1
#
#                                                     SQL  \
# name
# Плазморезчик                                          0
# Оператор станков с ЧПУ                                0
# Оператор 1C                                           0
# Программист 1C                                        0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд     0
# ...                                                 ...
# Инженер-программист АСУ ТП                            0
# Junior бизнес-аналитик                                0
# Менеджер по проектам                                  0
# Менеджер проектов (Project Manager) / Руководит...    0
# Рабочий по комплексному обслуживанию и ремонту ...    0
#
#                                                     Работа с большим объемом информации  \
# name
# Плазморезчик                                                                          0
# Оператор станков с ЧПУ                                                                0
# Оператор 1C                                                                           0
# Программист 1C                                                                        0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                                     0
# ...                                                                                 ...
# Инженер-программист АСУ ТП                                                            0
# Junior бизнес-аналитик                                                                0
# Менеджер по проектам                                                                  0
# Менеджер проектов (Project Manager) / Руководит...                                    0
# Рабочий по комплексному обслуживанию и ремонту ...                                    0
#
#                                                     Adobe Photoshop  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Настройка ПК  ...  \
# name                                                              ...
# Плазморезчик                                                   0  ...
# Оператор станков с ЧПУ                                         0  ...
# Оператор 1C                                                    0  ...
# Программист 1C                                                 0  ...
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд              0  ...
# ...                                                          ...  ...
# Инженер-программист АСУ ТП                                     0  ...
# Junior бизнес-аналитик                                         0  ...
# Менеджер по проектам                                           0  ...
# Менеджер проектов (Project Manager) / Руководит...             0  ...
# Рабочий по комплексному обслуживанию и ремонту ...             0  ...
#
#                                                     Информационная безопасность  \
# name
# Плазморезчик                                                                  0
# Оператор станков с ЧПУ                                                        0
# Оператор 1C                                                                   0
# Программист 1C                                                                0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                             0
# ...                                                                         ...
# Инженер-программист АСУ ТП                                                    0
# Junior бизнес-аналитик                                                        0
# Менеджер по проектам                                                          0
# Менеджер проектов (Project Manager) / Руководит...                            0
# Рабочий по комплексному обслуживанию и ремонту ...                            0
#
#                                                     PostgreSQL  1С  \
# name
# Плазморезчик                                                 0   0
# Оператор станков с ЧПУ                                       0   0
# Оператор 1C                                                  0   1
# Программист 1C                                               0   1
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд            0   0
# ...                                                        ...  ..
# Инженер-программист АСУ ТП                                   0   0
# Junior бизнес-аналитик                                       0   1
# Менеджер по проектам                                         0   0
# Менеджер проектов (Project Manager) / Руководит...           0   0
# Рабочий по комплексному обслуживанию и ремонту ...           0   0
#
#                                                     Фрезеровщик  \
# name
# Плазморезчик                                                  0
# Оператор станков с ЧПУ                                        0
# Оператор 1C                                                   0
# Программист 1C                                                0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд             0
# ...                                                         ...
# Инженер-программист АСУ ТП                                    0
# Junior бизнес-аналитик                                        0
# Менеджер по проектам                                          0
# Менеджер проектов (Project Manager) / Руководит...            0
# Рабочий по комплексному обслуживанию и ремонту ...            0
#
#                                                     Оператор станка  \
# name
# Плазморезчик                                                      0
# Оператор станков с ЧПУ                                            0
# Оператор 1C                                                       0
# Программист 1C                                                    0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                 0
# ...                                                             ...
# Инженер-программист АСУ ТП                                        0
# Junior бизнес-аналитик                                            0
# Менеджер по проектам                                              0
# Менеджер проектов (Project Manager) / Руководит...                0
# Рабочий по комплексному обслуживанию и ремонту ...                0
#
#                                                     Region_Волго-Уральский  \
# name
# Плазморезчик                                                             0
# Оператор станков с ЧПУ                                                   1
# Оператор 1C                                                              0
# Программист 1C                                                           0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                        0
# ...                                                                    ...
# Инженер-программист АСУ ТП                                               0
# Junior бизнес-аналитик                                                   0
# Менеджер по проектам                                                     0
# Менеджер проектов (Project Manager) / Руководит...                       0
# Рабочий по комплексному обслуживанию и ремонту ...                       0
#
#                                                     Region_Дальневосточный  \
# name
# Плазморезчик                                                             0
# Оператор станков с ЧПУ                                                   0
# Оператор 1C                                                              0
# Программист 1C                                                           0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                        0
# ...                                                                    ...
# Инженер-программист АСУ ТП                                               0
# Junior бизнес-аналитик                                                   1
# Менеджер по проектам                                                     0
# Менеджер проектов (Project Manager) / Руководит...                       0
# Рабочий по комплексному обслуживанию и ремонту ...                       0
#
#                                                     Region_Неизвестно  \
# name
# Плазморезчик                                                        0
# Оператор станков с ЧПУ                                              0
# Оператор 1C                                                         0
# Программист 1C                                                      0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                   0
# ...                                                               ...
# Инженер-программист АСУ ТП                                          0
# Junior бизнес-аналитик                                              0
# Менеджер по проектам                                                0
# Менеджер проектов (Project Manager) / Руководит...                  0
# Рабочий по комплексному обслуживанию и ремонту ...                  0
#
#                                                     Region_Северно-Западный  \
# name
# Плазморезчик                                                              0
# Оператор станков с ЧПУ                                                    0
# Оператор 1C                                                               0
# Программист 1C                                                            0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                         0
# ...                                                                     ...
# Инженер-программист АСУ ТП                                                0
# Junior бизнес-аналитик                                                    0
# Менеджер по проектам                                                      0
# Менеджер проектов (Project Manager) / Руководит...                        0
# Рабочий по комплексному обслуживанию и ремонту ...                        1
#
#                                                     Region_Центральный
# name
# Плазморезчик                                                         0
# Оператор станков с ЧПУ                                               0
# Оператор 1C                                                          0
# Программист 1C                                                       0
# Бренд-шеф повар / разработчик новых блюд Фаст-фуд                    1
# ...                                                                ...
# Инженер-программист АСУ ТП                                           0
# Junior бизнес-аналитик                                               0
# Менеджер по проектам                                                 1
# Менеджер проектов (Project Manager) / Руководит...                   0
# Рабочий по комплексному обслуживанию и ремонту ...                   0
#
# [16115 rows x 41 columns]
